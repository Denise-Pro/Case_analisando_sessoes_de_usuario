# %%
# instalar as dependências
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-2.4.4/spark-2.4.4-bin-hadoop2.7.tgz
# !tar xf spark-2.4.4-bin-hadoop2.7.tgz
# !pip install -q findspark

# configurar as variáveis de ambiente
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.4-bin-hadoop2.7"

# tornar o pyspark "importável"
import findspark
findspark.init('spark-2.4.4-bin-hadoop2.7')


from pyspark.sql import SparkSession
sc = SparkSession.builder.master('local[*]').getOrCreate()
from pyspark.sql import *

# %%
# download do http para arquivo local
# !wget --quiet --show-progress https://d3l36jjwr70u5l.cloudfront.net/data-engineer-test/part-00000.json.gz
# !wget --quiet --show-progress https://d3l36jjwr70u5l.cloudfront.net/data-engineer-test/part-00001.json.gz
# !wget --quiet --show-progress https://d3l36jjwr70u5l.cloudfront.net/data-engineer-test/part-00002.json.gz
# !wget --quiet --show-progress https://d3l36jjwr70u5l.cloudfront.net/data-engineer-test/part-00003.json.gz
# !wget --quiet --show-progress https://d3l36jjwr70u5l.cloudfront.net/data-engineer-test/part-00004.json.gz
# !wget --quiet --show-progress https://d3l36jjwr70u5l.cloudfront.net/data-engineer-test/part-00005.json.gz
# !wget --quiet --show-progress https://d3l36jjwr70u5l.cloudfront.net/data-engineer-test/part-00006.json.gz
# !wget --quiet --show-progress https://d3l36jjwr70u5l.cloudfront.net/data-engineer-test/part-00007.json.gz
# !wget --quiet --show-progress https://d3l36jjwr70u5l.cloudfront.net/data-engineer-test/part-00008.json.gz
# !wget --quiet --show-progress https://d3l36jjwr70u5l.cloudfront.net/data-engineer-test/part-00009.json.gz
# Out:
# part-00000.json.gz  100%[===================>] 323.41M   217MB/s    in 1.5s
# part-00001.json.gz  100%[===================>] 323.28M   202MB/s    in 1.6s
# part-00002.json.gz  100%[===================>] 323.18M  29.2MB/s    in 12s
# part-00003.json.gz  100%[===================>] 323.35M  29.2MB/s    in 12s
# part-00004.json.gz  100%[===================>] 323.35M  29.1MB/s    in 12s
# part-00005.json.gz  100%[===================>] 323.41M  29.3MB/s    in 12s
# part-00006.json.gz  100%[===================>] 323.33M  29.4MB/s    in 12s
# part-00007.json.gz  100%[===================>] 323.43M  29.2MB/s    in 12s
# part-00008.json.gz  100%[===================>] 323.21M  29.3MB/s    in 12s
# part-00009.json.gz  100%[===================>] 323.22M   203MB/s    in 1.6s

# %%
from pyspark.sql import functions as f
from pyspark.sql import types as t

# carregando dados dos arquivos json em dataframes
df_spark_json_0 = sc.read.json("./part-00000.json.gz")
df_spark_json_1 = sc.read.json("./part-00001.json.gz")
df_spark_json_2 = sc.read.json("./part-00002.json.gz")
df_spark_json_3 = sc.read.json("./part-00003.json.gz")
df_spark_json_4 = sc.read.json("./part-00004.json.gz")
df_spark_json_5 = sc.read.json("./part-00005.json.gz")
df_spark_json_6 = sc.read.json("./part-00006.json.gz")
df_spark_json_7 = sc.read.json("./part-00007.json.gz")
df_spark_json_8 = sc.read.json("./part-00008.json.gz")
df_spark_json_9 = sc.read.json("./part-00009.json.gz")

# %%
# converto aqui o formato epoch da coluna device_sent_timestamp para um formato timestamp legível

df_spark_jdf_spark_json_0 = df_spark_json_0.withColumn('device_sent_timestamp',(df_spark_json_0.device_sent_timestamp/1000).cast("timestamp").alias("timestamp"))
df_spark_jdf_spark_json_1 = df_spark_json_1.withColumn('device_sent_timestamp',(df_spark_json_1.device_sent_timestamp/1000).cast("timestamp").alias("timestamp"))
df_spark_jdf_spark_json_2 = df_spark_json_2.withColumn('device_sent_timestamp',(df_spark_json_2.device_sent_timestamp/1000).cast("timestamp").alias("timestamp"))
df_spark_jdf_spark_json_3 = df_spark_json_3.withColumn('device_sent_timestamp',(df_spark_json_3.device_sent_timestamp/1000).cast("timestamp").alias("timestamp"))
df_spark_jdf_spark_json_4 = df_spark_json_4.withColumn('device_sent_timestamp',(df_spark_json_4.device_sent_timestamp/1000).cast("timestamp").alias("timestamp"))
df_spark_jdf_spark_json_5 = df_spark_json_5.withColumn('device_sent_timestamp',(df_spark_json_5.device_sent_timestamp/1000).cast("timestamp").alias("timestamp"))
df_spark_jdf_spark_json_6 = df_spark_json_6.withColumn('device_sent_timestamp',(df_spark_json_6.device_sent_timestamp/1000).cast("timestamp").alias("timestamp"))
df_spark_jdf_spark_json_7 = df_spark_json_7.withColumn('device_sent_timestamp',(df_spark_json_7.device_sent_timestamp/1000).cast("timestamp").alias("timestamp"))
df_spark_jdf_spark_json_8 = df_spark_json_8.withColumn('device_sent_timestamp',(df_spark_json_8.device_sent_timestamp/1000).cast("timestamp").alias("timestamp"))
df_spark_jdf_spark_json_9 = df_spark_json_9.withColumn('device_sent_timestamp',(df_spark_json_9.device_sent_timestamp/1000).cast("timestamp").alias("timestamp"))

# %%
# faço aqui a uniaõ de todos os arquivos particionados
df = df_spark_json_0.union(df_spark_json_1).union(df_spark_json_2)\
  .union(df_spark_json_3).union(df_spark_json_4).union(df_spark_json_5)\
  .union(df_spark_json_6).union(df_spark_json_7).union(df_spark_json_8).union(df_spark_json_9)
df = df.withColumn('device_sent_timestamp',(df.device_sent_timestamp/1000).cast("timestamp").alias("timestamp"))
df.show()
# Out:
# +--------------------+--------------+------------------+---------------------+--------+---+---------+--------+-------+
# |        anonymous_id|browser_family|     device_family|device_sent_timestamp|   event|  n|os_family|platform|version|
# +--------------------+--------------+------------------+---------------------+--------+---+---------+--------+-------+
# |46074eab-28f7-483...| Chrome Mobile|  Samsung SM-A105M| 2020-06-20 01:32:...|pageview| 82|  Android|     web|    1.0|
# |24c1f50c-c192-4f8...| Chrome Mobile|  Samsung SM-A105M| 2020-06-20 01:17:...|pageview| 82|  Android|     web|    1.0|
# |2c7ed100-3e30-4c1...| Chrome Mobile|  Samsung SM-A105M| 2020-06-20 03:39:...|pageview| 82|  Android|     web|    1.0|
# |38e159c7-e228-401...| Chrome Mobile|  Samsung SM-A105M| 2020-06-20 01:55:...|pageview| 82|  Android|     web|    1.0|
# |724f1899-1308-4db...| Chrome Mobile|  Samsung SM-A105M| 2020-06-19 23:26:...|pageview| 82|  Android|     web|    1.0|
# |e026cd00-9cdc-426...| Chrome Mobile|  Samsung SM-A105M| 2020-06-20 00:03:...|pageview| 82|  Android|     web|    1.0|
# |d23cce8d-945f-422...| Chrome Mobile|  Samsung SM-A105M| 2020-06-19 23:44:...|pageview| 82|  Android|     web|    1.0|
# |5de44230-1e95-4df...| Chrome Mobile|  Samsung SM-A105M| 2020-06-20 02:59:...|pageview| 82|  Android|     web|    1.0|
# |4355dfbf-aa13-4fc...| Chrome Mobile|  Samsung SM-A105M| 2020-06-20 01:12:...|pageview| 82|  Android|     web|    1.0|
# |c2fd1be3-7aa1-4b9...| Chrome Mobile|  Samsung SM-A105M| 2020-06-20 02:04:...|pageview| 82|  Android|     web|    1.0|
# |8b1c0442-a762-4af...| Chrome Mobile|  Samsung SM-A105M| 2020-06-20 01:21:...|pageview| 82|  Android|     web|    1.0|
# |1a3f0236-a080-444...|      Facebook|Generic Smartphone| 2020-06-20 01:54:...|pageview| 48|  Android|     web|    1.0|
# |eae3773a-85b4-402...|      Facebook|Generic Smartphone| 2020-06-20 01:02:...|pageview| 48|  Android|     web|    1.0|
# |26c5ca70-dccc-4e4...|      Facebook|Generic Smartphone| 2020-06-20 02:32:...|pageview| 48|  Android|     web|    1.0|
# |bfb19bb4-72cd-45e...| Mobile Safari|            iPhone| 2020-06-20 01:55:...|pageview| 26|      iOS|     web|    1.0|
# |9e4d2af4-17c4-4ca...| Mobile Safari|            iPhone| 2020-06-20 02:35:...|pageview| 26|      iOS|     web|    1.0|
# |07f496f0-6682-4b9...| Mobile Safari|            iPhone| 2020-06-20 02:54:...|pageview| 26|      iOS|     web|    1.0|
# |314a8261-5515-4f3...| Mobile Safari|            iPhone| 2020-06-20 01:42:...|pageview| 26|      iOS|     web|    1.0|
# |836e5243-fcec-4ef...| Mobile Safari|            iPhone| 2020-06-20 00:48:...|pageview| 26|      iOS|     web|    1.0|
# |3436ac09-39f3-480...| Mobile Safari|            iPhone| 2020-06-20 01:21:...|pageview| 26|      iOS|     web|    1.0|
# +--------------------+--------------+------------------+---------------------+--------+---+---------+--------+-------+
# only showing top 20 rows

# %%
df_spark_jdf_spark_json_9
# Out:
# DataFrame[anonymous_id: string, browser_family: string, device_family: string, device_sent_timestamp: timestamp, event: string, n: bigint, os_family: string, platform: string, version: string]

# %%
df_spark_jdf_spark_json_9.show()
# Out:
# +--------------------+--------------+-----------------+---------------------+--------+---+----------+--------+-------+
# |        anonymous_id|browser_family|    device_family|device_sent_timestamp|   event|  n| os_family|platform|version|
# +--------------------+--------------+-----------------+---------------------+--------+---+----------+--------+-------+
# |af7b41ca-d961-44a...|     Googlebot|           Spider| 2020-06-12 04:09:...|pageview| 57|     Other|     web|    1.0|
# |63653a22-0c6c-495...|     Googlebot|           Spider| 2020-06-12 01:00:...|pageview| 57|     Other|     web|    1.0|
# |179680a8-d843-4f6...|     Googlebot|           Spider| 2020-06-12 01:33:...|pageview| 57|     Other|     web|    1.0|
# |15d24bf9-e331-46f...|     Googlebot|           Spider| 2020-06-12 03:30:...|pageview| 57|     Other|     web|    1.0|
# |90597a6f-d3a6-443...|     Googlebot|           Spider| 2020-06-12 02:24:...|pageview| 57|     Other|     web|    1.0|
# |722adfbc-273c-407...|        Safari|            Other| 2020-06-12 17:34:...|pageview| 73|  Mac OS X|     web|    1.0|
# |02de564c-fdc6-4d2...|        Safari|            Other| 2020-06-12 18:29:...|pageview| 73|  Mac OS X|     web|    1.0|
# |e9851c2e-1143-468...|        Safari|            Other| 2020-06-12 20:30:...|pageview| 73|  Mac OS X|     web|    1.0|
# |c9a835d5-2fa2-428...|        Safari|            Other| 2020-06-12 17:38:...|pageview| 73|  Mac OS X|     web|    1.0|
# |c6a76a80-22d8-484...|        Safari|            Other| 2020-06-12 19:53:...|pageview| 73|  Mac OS X|     web|    1.0|
# |0479f1ac-f7e3-453...|        Chrome|            Other| 2020-06-12 19:57:...|pageview| 18|Windows 10|     web|    1.0|
# |cabf731f-1a51-491...| Chrome Mobile|Samsung SM-A505GT| 2020-06-12 19:21:...|pageview| 76|   Android|     web|    1.0|
# |3f533f94-f19c-432...| Chrome Mobile|Samsung SM-A505GT| 2020-06-12 17:11:...|pageview| 76|   Android|     web|    1.0|
# |de3efced-6b61-478...| Chrome Mobile|Samsung SM-A505GT| 2020-06-12 19:27:...|pageview| 76|   Android|     web|    1.0|
# |9de90e81-c5c9-47d...| Chrome Mobile|Samsung SM-A505GT| 2020-06-12 18:31:...|pageview| 76|   Android|     web|    1.0|
# |b129aab2-75ce-451...| Chrome Mobile|Samsung SM-A505GT| 2020-06-12 18:28:...|pageview| 76|   Android|     web|    1.0|
# |85dd7abb-8d38-481...| Chrome Mobile|Samsung SM-A505GT| 2020-06-12 18:40:...|pageview| 76|   Android|     web|    1.0|
# |d36e8191-eb99-42a...| Chrome Mobile|Samsung SM-A505GT| 2020-06-12 20:21:...|pageview| 76|   Android|     web|    1.0|
# |df31ae0f-27c0-46a...|      Facebook| Samsung SM-J610G| 2020-06-12 19:10:...|pageview|  8|   Android|     web|    1.0|
# |34a391a5-e7dd-4bf...|      Facebook| Samsung SM-J610G| 2020-06-12 18:54:...|pageview|  8|   Android|     web|    1.0|
# +--------------------+--------------+-----------------+---------------------+--------+---+----------+--------+-------+
# only showing top 20 rows

# %% [markdown]
# Através do agrupamento de id de usuários, Identifico aqui se há algum id de usuário que se repita - em todos os dataframes

# %%
df_spark_jdf_spark_json_9.groupBy('anonymous_id').count().show()
# Out:
# +--------------------+-----+
# |        anonymous_id|count|
# +--------------------+-----+
# |c9a835d5-2fa2-428...|    1|
# |9de90e81-c5c9-47d...|    1|
# |a8062312-3bb3-4ff...|    1|
# |79da11d5-7d5c-468...|    1|
# |fee1d0da-708e-4e9...|    1|
# |590f876a-a864-402...|    1|
# |3035cb37-66fa-4da...|    1|
# |f9af0f3d-28f2-402...|    1|
# |c370bcd6-b4d7-4f3...|    1|
# |c821bd1d-9c98-459...|    1|
# |96c93315-fb08-46d...|    1|
# |d6d734d2-06c0-4e7...|    1|
# |9edb5140-f66b-49a...|    1|
# |510d6995-732a-4fe...|    1|
# |b80becba-854b-48d...|    1|
# |5aaadf9b-0dfd-46d...|    1|
# |90397e1d-79de-4ac...|    1|
# |c384a59e-8db5-4ea...|    1|
# |e579034b-a8ef-450...|    1|
# |63407234-f2a8-437...|    1|
# +--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# #**Etapa 1**
# ### Ao perceber que não há repetições nas colunas de usuário('anonymous_id') em nenhum dos arquivos particionados e que não há um tempo inicial e final para um mesmo usuário, para que eu possa contabilizar o tempo de uma sessão, eu assumo que cada linha da coluna 'anonymous id' é uma sessão de usuário diferente. Sendo assim , uma contagem nessa coluna me dará o número total de sessões únicas

# %%
dict = {}
# count = df_spark_json_0.select(df_spark_json_0.anonymous_id).count()
dict.update({'part-00000.json.gz': df_spark_json_0.select('anonymous_id').count()})
dict.update({'part-00001.json.gz': df_spark_json_1.select('anonymous_id').count()})
dict.update({'part-00002.json.gz': df_spark_json_2.select('anonymous_id').count()})
dict.update({'part-00003.json.gz': df_spark_json_3.select('anonymous_id').count()})
dict.update({'part-00004.json.gz': df_spark_json_4.select('anonymous_id').count()})
dict.update({'part-00005.json.gz': df_spark_json_5.select('anonymous_id').count()})
dict.update({'part-00006.json.gz': df_spark_json_6.select('anonymous_id').count()})
dict.update({'part-00007.json.gz': df_spark_json_7.select('anonymous_id').count()})
dict.update({'part-00008.json.gz': df_spark_json_8.select('anonymous_id').count()})
dict.update({'part-00009.json.gz': df_spark_json_9.select('anonymous_id').count()})
dict
# Out:
# {'part-00000.json.gz': 10235120,
#  'part-00001.json.gz': 10230783,
#  'part-00002.json.gz': 10227571,
#  'part-00003.json.gz': 10233334,
#  'part-00004.json.gz': 10233316,
#  'part-00005.json.gz': 10235214,
#  'part-00006.json.gz': 10232664,
#  'part-00007.json.gz': 10236342,
#  'part-00008.json.gz': 10228151,
#  'part-00009.json.gz': 10229051}

# %% [markdown]
# #**Etapa 2**

# %%
# faço aqui a uniaõ de todos os arquivos particionados
df = df_spark_json_0.union(df_spark_json_1).union(df_spark_json_2)\
  .union(df_spark_json_3).union(df_spark_json_4).union(df_spark_json_5)\
  .union(df_spark_json_6).union(df_spark_json_7).union(df_spark_json_8).union(df_spark_json_9)
df.show()
# Out:
# +--------------------+--------------+------------------+---------------------+--------+---+---------+--------+-------+
# |        anonymous_id|browser_family|     device_family|device_sent_timestamp|   event|  n|os_family|platform|version|
# +--------------------+--------------+------------------+---------------------+--------+---+---------+--------+-------+
# |46074eab-28f7-483...| Chrome Mobile|  Samsung SM-A105M|        1592616733778|pageview| 82|  Android|     web|    1.0|
# |24c1f50c-c192-4f8...| Chrome Mobile|  Samsung SM-A105M|        1592615846912|pageview| 82|  Android|     web|    1.0|
# |2c7ed100-3e30-4c1...| Chrome Mobile|  Samsung SM-A105M|        1592624340522|pageview| 82|  Android|     web|    1.0|
# |38e159c7-e228-401...| Chrome Mobile|  Samsung SM-A105M|        1592618132135|pageview| 82|  Android|     web|    1.0|
# |724f1899-1308-4db...| Chrome Mobile|  Samsung SM-A105M|        1592609177603|pageview| 82|  Android|     web|    1.0|
# |e026cd00-9cdc-426...| Chrome Mobile|  Samsung SM-A105M|        1592611382049|pageview| 82|  Android|     web|    1.0|
# |d23cce8d-945f-422...| Chrome Mobile|  Samsung SM-A105M|        1592610274812|pageview| 82|  Android|     web|    1.0|
# |5de44230-1e95-4df...| Chrome Mobile|  Samsung SM-A105M|        1592621983715|pageview| 82|  Android|     web|    1.0|
# |4355dfbf-aa13-4fc...| Chrome Mobile|  Samsung SM-A105M|        1592615545409|pageview| 82|  Android|     web|    1.0|
# |c2fd1be3-7aa1-4b9...| Chrome Mobile|  Samsung SM-A105M|        1592618660078|pageview| 82|  Android|     web|    1.0|
# |8b1c0442-a762-4af...| Chrome Mobile|  Samsung SM-A105M|        1592616096920|pageview| 82|  Android|     web|    1.0|
# |1a3f0236-a080-444...|      Facebook|Generic Smartphone|        1592618041631|pageview| 48|  Android|     web|    1.0|
# |eae3773a-85b4-402...|      Facebook|Generic Smartphone|        1592614926618|pageview| 48|  Android|     web|    1.0|
# |26c5ca70-dccc-4e4...|      Facebook|Generic Smartphone|        1592620330677|pageview| 48|  Android|     web|    1.0|
# |bfb19bb4-72cd-45e...| Mobile Safari|            iPhone|        1592618144935|pageview| 26|      iOS|     web|    1.0|
# |9e4d2af4-17c4-4ca...| Mobile Safari|            iPhone|        1592620523645|pageview| 26|      iOS|     web|    1.0|
# |07f496f0-6682-4b9...| Mobile Safari|            iPhone|        1592621658736|pageview| 26|      iOS|     web|    1.0|
# |314a8261-5515-4f3...| Mobile Safari|            iPhone|        1592617332970|pageview| 26|      iOS|     web|    1.0|
# |836e5243-fcec-4ef...| Mobile Safari|            iPhone|        1592614118376|pageview| 26|      iOS|     web|    1.0|
# |3436ac09-39f3-480...| Mobile Safari|            iPhone|        1592616113247|pageview| 26|      iOS|     web|    1.0|
# +--------------------+--------------+------------------+---------------------+--------+---+---------+--------+-------+
# only showing top 20 rows

# %%
#verifico se a quantidade de linhas desse novo dataframe bate com a quantidade de linhas somadas de todos os arquivos particionados - 
# cada file tem aproximadamente 10 milhoes de lihas - a qtd bate com o esperado!
df.count()
# Out:
# 102321546

# %%
df_br = df.groupBy('browser_family').count().toPandas()

# %%
df_br
# Out:
#                  browser_family     count
# 0                   Edge Mobile      3274
# 1                  Opera Mobile     75357
# 2                     AppleMail       751
# 3                       Firefox    763711
# 4                       Vivaldi      1257
# 5                     SeaMonkey        25
# 6                   Amazon Silk      1313
# 7                        Safari    161855
# 8                         Other   2489787
# 9       Mobile Safari UIWebView   4365301
# 10           Investment Crawler         3
# 11                Chrome Mobile  51526442
# 12                     PetalBot      1155
# 13                  Firefox iOS      8097
# 14                       Puffin      2400
# 15               Yandex Browser      1894
# 16                AdsBot-Google    113649
# 17               Firefox Mobile    125298
# 18                     Chromium      6110
# 19                       SMTBot       284
# 20                Mobile Safari   4707652
# 21                   Opera Mini       223
# 22                    Googlebot   7978243
# 23                GooglePlusBot       139
# 24                     Applebot        73
# 25                 Yahoo! Slurp        72
# 26                    Pinterest        62
# 27  Pale Moon (Firefox Variant)       150
# 28            Chrome Mobile iOS    690819
# 29                      Android       404
# 30                           IE       104
# 31                      Maxthon       193
# 32                       Chrome  11206495
# 33                  BingPreview       334
# 34                   UC Browser     38617
# 35                         Edge     85378
# 36                    IE Mobile        68
# 37                     Facebook  17789908
# 38                        Opera    174649

# %%
list_browser = df_br.browser_family.values
list_browser_values = df_br['count'].values

# %%
dict_browser = {}
for i in range(len(list_browser)):
  dict_browser.update({list_browser[i]: list_browser_values[i]})
dict_browser
# Out:
# {'AdsBot-Google': 113649,
#  'Amazon Silk': 1313,
#  'Android': 404,
#  'AppleMail': 751,
#  'Applebot': 73,
#  'BingPreview': 334,
#  'Chrome': 11206495,
#  'Chrome Mobile': 51526442,
#  'Chrome Mobile iOS': 690819,
#  'Chromium': 6110,
#  'Edge': 85378,
#  'Edge Mobile': 3274,
#  'Facebook': 17789908,
#  'Firefox': 763711,
#  'Firefox Mobile': 125298,
#  'Firefox iOS': 8097,
#  'GooglePlusBot': 139,
#  'Googlebot': 7978243,
#  'IE': 104,
#  'IE Mobile': 68,
#  'Investment Crawler': 3,
#  'Maxthon': 193,
#  'Mobile Safari': 4707652,
#  'Mobile Safari UIWebView': 4365301,
#  'Opera': 174649,
#  'Opera Mini': 223,
#  'Opera Mobile': 75357,
#  'Other': 2489787,
#  'Pale Moon (Firefox Variant)': 150,
#  'PetalBot': 1155,
#  'Pinterest': 62,
#  'Puffin': 2400,
#  'SMTBot': 284,
#  'Safari': 161855,
#  'SeaMonkey': 25,
#  'UC Browser': 38617,
#  'Vivaldi': 1257,
#  'Yahoo! Slurp': 72,
#  'Yandex Browser': 1894}

# %%
df_device = df.groupBy('device_family').count().toPandas()

# %%
df_device
# Out:
#         device_family   count
# 0          iPhone11,2   56001
# 1            MS50L_4G    1189
# 2      XiaoMi Redmi 7   62385
# 3     XiaoMi Redmi Go   23643
# 4               KYY23     140
# ...               ...     ...
# 1298            RS988     369
# 1299            G3223     117
# 1300       Asus A001D  107105
# 1301        Skywalker     417
# 1302  Lenovo A3300-GV     199
#
# [1303 rows x 2 columns]

# %%
list_devices = df_device.device_family.values
list_devices_values =  df_device['count'].values
# Out:
# array([ 56001,   1189,  62385, ..., 107105,    417,    199])

# %%
dict_devices = {}
for i in range(len(list_devices)):
  dict_devices.update({list_devices[i]:list_devices_values[i]})
dict_devices
# Out:
# {'iPhone11,2': 56001,
#  'MS50L_4G': 1189,
#  'XiaoMi Redmi 7': 62385,
#  'XiaoMi Redmi Go': 23643,
#  'KYY23': 140,
#  'Samsung SM-G970N': 406,
#  'iPad6,12': 44,
#  'Samsung SM-A730F': 74534,
#  'ML-TI-MS80': 1455,
#  'Samsung SM-G770F': 2166,
#  'XT1225': 1983,
#  'Pixel 2 XL': 32,
#  'KING 7': 37,
#  'MZ-MX4': 6,
#  'Samsung SM-J260M': 372689,
#  'LG-D337': 53540,
#  '5159J': 10077,
#  'Lenovo K53b36': 39969,
#  'Samsung SM-T865': 321,
#  'LG-V480': 42,
#  'XiaoMi Redmi S2': 28957,
#  'ZE553KL': 7205,
#  'S60': 147,
#  'C6': 775,
#  'M7_3G_PLUS': 1368,
#  'BLU NEO X MINI': 177,
#  'XT621': 25,
#  'Samsung SM-T705M': 436,
#  'Grand X': 648,
#  'XT1585': 77,
#  'Samsung SM-T285YD': 463,
#  'Samsung SM-T330': 27,
#  'Nokia 2': 3076,
#  'MZ-M5 Note': 15,
#  'Samsung SM-G935T': 3,
#  'iPhone6,2': 80690,
#  'LG-H502': 4487,
#  'Samsung SM-N960F': 5147,
#  'C6943': 1452,
#  'Samsung GT-S7583T': 1052,
#  'Moto X4': 26,
#  'ZTE Blade L5': 287,
#  'XiaoMi Redmi 6': 54770,
#  'LG-H860': 1725,
#  'LG-H342': 4611,
#  'MS55M': 646,
#  'Samsung SM-N976U': 669,
#  'MX9-4K': 76,
#  'Samsung SM-A507FN': 48,
#  'HTC 10 evo': 41,
#  'Spider': 8092463,
#  'Z Play': 523,
#  'Sky': 1861,
#  'Samsung SM-T561M': 179,
#  'Samsung SM-G920V': 1314,
#  'MN4A2ZP/A': 261,
#  'Lenovo K10a40': 32925,
#  'NX591J': 734,
#  'Samsung SM-A700FD': 6433,
#  'Samsung SM-A202F': 1195,
#  'Samsung SM-T110': 272,
#  'Meizu M6s': 178,
#  'U2': 143,
#  'Samsung SM-G950F': 239451,
#  'Samsung SM-G935U': 190,
#  'Samsung SM-G960U': 1418,
#  'LG-H831': 192,
#  'TV BOX': 96,
#  'Samsung SM-G530T': 409,
#  'Archos Core 50 4G': 774,
#  'Samsung SM-G316M': 282,
#  'LG-H221': 839,
#  'iPad': 44369,
#  'Moto G (5S) Plus': 368610,
#  'MotoE2(4G-LTE)': 5116,
#  '5085N': 5142,
#  'Samsung SM-G9750': 135,
#  'Moto G (4)': 158121,
#  'G_Pro': 1833,
#  'G3311': 132,
#  'Lenovo TB2-X30F': 573,
#  'X21 Plus': 74,
#  'D5803': 17,
#  'LG-H931': 68,
#  'Samsung SM-J701MT': 417172,
#  'Samsung SM-A750G': 177630,
#  'Positivo Twist 4G': 5722,
#  'Samsung SM-G973U1': 982,
#  'M10A': 43,
#  'Lumia 950': 56,
#  'iPad3,5': 735,
#  'Samsung SM-N950U': 1089,
#  'Samsung SM-G3502T': 888,
#  '5016J': 973,
#  'D5833': 220,
#  'Samsung SM-A530F': 122161,
#  'XiaoMi Redmi 8': 55127,
#  'Grand XL': 167,
#  '91S': 43,
#  'Samsung SM-G850F': 330,
#  'Samsung SM-T311': 30,
#  'Samsung SM-A520F': 123547,
#  'Samsung SM-N935F': 281,
#  'Vivo 5 Mini': 253,
#  'HS007C': 70,
#  'XiaoMi MI 9': 74411,
#  'Asus X00TDB': 61365,
#  'Positivo Slim': 1294,
#  'VFD 620': 130,
#  'Samsung SM-A750GN': 337,
#  'XT1563': 782,
#  'Samsung SM-G9730': 23,
#  'LEX651': 216,
#  'Samsung SM-J250F': 103,
#  'iPhone10,4': 322985,
#  'LG-D385': 2031,
#  'You L': 848,
#  'Samsung SM-J415FN': 478,
#  'BBC100-1': 19,
#  'Moto E': 650,
#  'Asus I001DD': 165,
#  'Samsung SM-J727U': 118,
#  'S10': 303,
#  'moto g6 plus': 157,
#  'F': 13276,
#  'XiaoMi Redmi Note 5': 47527,
#  'iPhone9,2': 72248,
#  'Lenovo A2016b30': 36655,
#  'PHONEMAX_Saturn': 99,
#  'DUB-LX3': 268,
#  'M7sLite': 213,
#  'X50A': 84,
#  'INE-LX1': 134,
#  'Archos 60 Platinum': 193,
#  'iPad3,3': 40,
#  'SGP311': 77,
#  'Samsung SM-J510FN': 104,
#  'iPhone7,2': 227841,
#  'Samsung SM-G600FY': 84674,
#  'MotoG3-TE': 4318,
#  'MIX 2': 618,
#  'E6653': 477,
#  'F5122': 1209,
#  'STV100-3': 887,
#  'moto g(6) plus': 13940,
#  'Nokia 7 plus': 112,
#  'LG-H326': 4368,
#  'Samsung SM-N960N': 1161,
#  'Samsung SM-G900F': 662,
#  'Platinum_5.0M': 169,
#  'Kingbox': 161,
#  'iPhone10,6': 178697,
#  'Positivo Twist M': 3378,
#  'Samsung SM-P585M': 1350,
#  'Samsung SM-P555M': 686,
#  'Samsung SM-A305FN': 85,
#  'ML-WI-M9-3G': 23,
#  'Samsung SM-G532M': 196982,
#  'LG-H815': 2720,
#  'Asus X00LDA': 12295,
#  'Samsung SM-J701F': 1961,
#  'Samsung SM-N910A': 1221,
#  'INE-LX2': 69,
#  'Samsung SM-J727T': 88,
#  'Samsung GT-S5303B': 87,
#  'Le X520': 5,
#  'XiaoMi MI 8': 23202,
#  'XT1025': 1234,
#  'Lenovo A7600-F': 33,
#  'XT1609': 50,
#  'D6643': 63,
#  'Samsung SM-G900H': 28,
#  'Nexus 5': 494614,
#  'Samsung SM-G935F': 137698,
#  'Samsung SM-T295': 2953,
#  'Armor_3': 5,
#  'MS80X': 1747,
#  'Samsung GT-I9505G': 32,
#  'HUAWEI LUA-U23': 49,
#  'T96 Mars': 40,
#  'MYA-L11': 465,
#  'Samsung GT-I8200L': 231,
#  'Asus Z00XS': 841,
#  'Samsung SM-P200': 99,
#  'Samsung SM-A920F': 90733,
#  'Samsung GT-I8190L': 619,
#  'Samsung GT-I8262B': 442,
#  'Samsung SM-N960U': 489,
#  'Samsung GT-P5210': 22,
#  'Twist Tab': 56,
#  'E6553': 251,
#  'BV8000Pro': 152,
#  'M5c': 289,
#  'Advance L4': 918,
#  'Nokia 2.3': 139,
#  'KFAUWI': 72,
#  'iPad7,3': 59,
#  'NV6': 18,
#  'LM-X210': 213072,
#  'XiaoMi Redmi Note 6 Pro': 65299,
#  'Samsung SM-G920I': 33530,
#  'Samsung SM-T555': 1990,
#  'Samsung GT-S7273T': 990,
#  'S8': 373,
#  'TVBOX': 195,
#  'GO3E': 5324,
#  'Huawei Browser': 1192,
#  '4009E': 134,
#  'Samsung SM-T585': 1916,
#  'LEX720': 183,
#  'M5s': 51,
#  'Samsung SM-J320F': 148,
#  'LG-K500n': 9,
#  'Samsung SM-G530H': 6556,
#  '1001-G Go': 2338,
#  'Armor_6': 222,
#  'MS50M': 436,
#  'Samsung SM-P205': 186,
#  'Power 3S': 63,
#  'Samsung GT-S7560M': 56,
#  'LG-K220': 71339,
#  'Samsung SM-G316ML': 265,
#  'S30': 194,
#  'S60Lite': 331,
#  'Samsung GT-I9082': 250,
#  'LG-D325': 2213,
#  'Samsung SM-A115M': 268,
#  '5017E': 127,
#  'Samsung SM-G928A': 109,
#  'Z971': 313,
#  'Samsung SM-J510MN': 123953,
#  'Samsung SM-J105M': 24233,
#  'XiaoMi Redmi 5': 4904,
#  'Samsung SM-J100M': 548,
#  'SUPER': 11,
#  'F_Pro': 1242,
#  'Samsung SM-G930T': 96,
#  'XiaoMi Redmi Note 5A': 332,
#  'Samsung SM-G6100': 923,
#  'Twist 2 Go': 115,
#  'XiaoMi Redmi K20': 311,
#  'Samsung SM-G130BU': 51,
#  'Asus X018D': 11949,
#  'XiaoMi Redmi Note 4': 14135,
#  'Samsung SM-G900M': 20158,
#  'LG-H870DS': 452,
#  'Samsung GT-P5200': 330,
#  'Samsung SM-G970X': 423,
#  'Le X620': 57,
#  'Samsung SM-G890A': 8,
#  'LG-K520': 107,
#  'Samsung SM-M205M': 51437,
#  'LM-X420': 15601,
#  'Samsung SM-N975F': 73657,
#  'Samsung SM-G955U': 1661,
#  'Samsung SM-T530': 15,
#  'HDT-7427G': 519,
#  'Samsung SM-A305GN': 90,
#  'Nokia 3.1 Plus': 152,
#  'X206': 47,
#  'LG-H930': 54,
#  'Positivo Twist S': 3271,
#  'MS50L': 29032,
#  'DUA-L22': 486,
#  'LG-X210': 1600,
#  'iPhone12,8': 2602,
#  'Samsung SM-A305G': 2087,
#  'K3': 261,
#  'Samsung SM-G9600': 274191,
#  'LG-M320G': 1,
#  'iPhone': 5372658,
#  'Samsung SM-A750FN': 236,
#  'Samsung SM-J320FN': 415,
#  'PTB7PAP_PTB7PAB_PTB7PAR': 252,
#  'D2212': 108,
#  'BLL-L23': 96,
#  'XT1799-2': 534,
#  'Samsung SM-A305GT': 717587,
#  'Asus Z00YD': 1725,
#  'LG-TP260': 46,
#  'Moto G 2014': 31,
#  'LG-D157f': 775,
#  'Samsung SM-J326AZ': 1055,
#  'Samsung SM-J330G': 995,
#  'E': 4072,
#  'iPhone5,1': 8924,
#  'Samsung SM-N915T': 554,
#  'Samsung SM-G900MD': 4806,
#  'XiaoMi MI A3': 113,
#  'HTC One M9': 2334,
#  'Asus X00QD': 67892,
#  '8050E': 17607,
#  'MONDIAL': 138,
#  'S430 Positivo Twist Mini': 1381,
#  'JSN-L21': 760,
#  'LG-H870S': 134,
#  'Lenovo K33a42': 386,
#  '5060D': 1,
#  'Samsung SM-J260MU': 4278,
#  'HT-705XS': 24,
#  'Samsung SM-J700T1': 518,
#  'Samsung SM-J106M': 136,
#  'iPhone11,6': 137381,
#  'LG-D410': 4228,
#  'GIONEE S11 lite': 38,
#  'LG-E435f': 392,
#  'iPad8,3': 116,
#  'Samsung SM-A600FN': 278,
#  'Samsung SM-J530F': 125,
#  'Nexus 5X': 650,
#  'iPhone10,1': 35516,
#  'Samsung GT-I9192': 18864,
#  'Samsung SM-G930U': 2282,
#  '4017F': 2451,
#  'XT1572': 933,
#  '2014819': 803,
#  'LG-E977': 118,
#  'Samsung SM-N9700': 63,
#  'Meizu M6': 115,
#  'LG-P705': 87,
#  'moto e5 play': 205677,
#  'XiaoMi Redmi Note 5A Prime': 2331,
#  'Moto X Play': 15157,
#  'POCOPHONE F1': 330,
#  'Twist Metal': 1513,
#  'XT1058': 562,
#  'Asus FBBD': 2900,
#  'XT1078': 1915,
#  'MS60X': 1466,
#  'E5563': 414,
#  'C103': 61,
#  'iPhone9,3': 594196,
#  'iPad3,4': 776,
#  'Samsung SM-J610FN': 437,
#  'Asus Z017DA': 637,
#  'Bluboo_S8_plus': 97,
#  'C5303': 32,
#  'S420': 110,
#  'Samsung SM-J200G': 134,
#  'moto e5': 166041,
#  'Lenovo K520': 1708,
#  'Moto G5S (XT1792)': 37,
#  'Samsung GT-I9200': 97,
#  'Samsung SM-A600GN': 98,
#  'Samsung SM-A715F': 76628,
#  'iPad7,6': 98,
#  'Asus Z00VD': 1063,
#  'LG-H222': 7967,
#  'Samsung GT-S5310B': 905,
#  '6039J': 211,
#  'Lenovo L38111': 302,
#  'STV-2000': 57,
#  'Samsung SM-J105B': 135938,
#  'Samsung SM-J730GM': 6051,
#  'Vivo XI+': 544,
#  'MS60F': 4428,
#  'MS50S': 104,
#  'itel A15': 70,
#  'Asus Z012DA': 164,
#  'LG-V500': 61,
#  'X23': 81,
#  'HUAWEI LYO-L21': 76,
#  'Moto G7 Plus': 2,
#  'Samsung GT-I8552B': 9405,
#  'Samsung SM-A105FN': 1622,
#  'HTC One M8': 209,
#  'LGMP260': 1518,
#  'G3313': 163,
#  'Samsung SM-A205GN': 337,
#  'LG-M700': 158408,
#  'Samsung SM-J200M': 21233,
#  'LG-H820': 154,
#  'BLU ENERGY DIAMOND': 96,
#  'MZ-Meizu M6s': 28,
#  'MYA-L23': 660,
#  'Samsung SM-G988U1': 18,
#  'LG-M150': 32,
#  'Tablet_DL_2810': 13,
#  'Samsung SM-G950U': 1767,
#  'Quantum You 2': 821,
#  '71S': 500,
#  '6060S': 71,
#  'Neffos C5': 303,
#  'XiaoMi MI 8 Lite': 224838,
#  'Samsung SM-G985F': 14687,
#  'MS40G': 7101,
#  'Asus Z00AD': 9642,
#  'iPhone5,2': 1219,
#  'Samsung GT-P3100': 146,
#  'vivo 1805': 6,
#  'LG-M400': 39875,
#  'Asus X017DA': 31090,
#  '4034E': 15214,
#  'Samsung SM-J710F': 1738,
#  'Samsung GT-S6293T': 5817,
#  'LG-H918': 90,
#  'iPad7,4': 55,
#  'XiaoMi Redmi Pro': 180,
#  'Samsung SM-G903F': 131,
#  'XT1706': 83,
#  'Samsung SM-T715Y': 158,
#  'Samsung SM-G970U': 74,
#  'Samsung SM-J400M': 321733,
#  'Samsung SM-J727T1': 147,
#  '9008J': 3824,
#  'Samsung SM-A102U': 538,
#  'ZUK Z2121': 341,
#  'XT1079': 1681,
#  'Samsung SM-G920F': 2297,
#  'VF-1397': 64,
#  'Lumia 435': 45,
#  'Moto C Plus': 155664,
#  'XT1032': 5631,
#  'Samsung SM-J700F': 3549,
#  'Samsung SM-C5010': 497,
#  'LG-H830': 187,
#  'Tablet_DL_2811': 1198,
#  'LG-E470f': 211,
#  'moto g7 plus': 114,
#  'Samsung SM-J415G': 480652,
#  'Lenovo K33a48': 5610,
#  'Asus X013D': 12506,
#  'MUV': 2292,
#  'C2004': 16,
#  'Twist XL': 2433,
#  'M7-4G': 1344,
#  'LG-K428': 28,
#  'Samsung SM-A107F': 483,
#  'LG-D285': 189,
#  '4028E': 27,
#  'Moto Z2 Play': 193927,
#  'Samsung SM-G988B': 2760,
#  'Samsung SM-J120AZ': 71,
#  'Samsung SM-G611M': 2637,
#  'Lenovo TB-X304F': 174,
#  'Samsung SM-T580': 122,
#  'XiaoMi Redmi 8A': 41738,
#  '4009I': 73,
#  'Grand M': 79,
#  'XT1064': 247,
#  'Samsung SM-A605G': 33,
#  'C5 2019': 10,
#  'LG-K410': 3338,
#  'Lenovo A1000': 518,
#  'D6603': 1206,
#  'Samsung SM-C7000': 159,
#  'LG-E455': 281,
#  'TRT-L53': 506,
#  'Asus X00HD': 11342,
#  'LG-H522': 7078,
#  'N5L': 54,
#  'XiaoMi Redmi 4': 239,
#  'F3313': 1241,
#  'Samsung SM-A920X': 28,
#  'Asus X018DC': 23,
#  'Samsung SM-G7102': 49,
#  'Life One X2 Mini': 80,
#  'Samsung GT-I9515': 154,
#  'Samsung SM-N770F': 6472,
#  'Samsung SM-J3110': 353,
#  'Samsung SM-A217M': 53,
#  'D6543': 1536,
#  'Asus X01AD': 300,
#  'NX563J': 305,
#  'E5343': 194,
#  'G011A': 55,
#  'Plus E': 36,
#  'Samsung SM-G925I': 23667,
#  'G3226': 2945,
#  'iPad4,2': 480,
#  'LG-H870V': 97,
#  'Asus Z00A': 252,
#  'Samsung SM-J3119S': 37,
#  'PRA-LX3': 9,
#  'LG-D295': 1472,
#  'iPad5,3': 620,
#  '5049E': 319,
#  'Lenovo TB3-X70F': 95,
#  'D2306': 126,
#  'Asus Z011D': 5497,
#  'Z2 Plus': 47,
#  'XT1662': 315,
#  'iPhone5,3': 307,
#  'DIG-L03': 43,
#  'XiaoMi MI 6X': 901,
#  'Samsung SM-A205G': 932514,
#  'XT1097': 8852,
#  'G3426': 1278,
#  'Samsung SM-G110B': 223,
#  'BLU DASH M2': 420,
#  'Samsung SM-J810Y': 103,
#  'Samsung SM-J327W': 44,
#  'Samsung SM-G850M': 153,
#  'Samsung SM-T285': 6,
#  'Advance 4.0M': 426,
#  'Asus Z017D': 859,
#  'M7S_LITE': 283,
#  'Mi MIX 2': 53,
#  'D2243': 115,
#  'Aquaris X Pro': 218,
#  'MS45S_A6_Teen': 102,
#  'Asus X014D': 587,
#  'Samsung SM-G925P': 21,
#  'Archos Access 50 Color 3G': 279,
#  'Le X820': 156,
#  'Samsung SM-G530A': 127,
#  'iPhone10,3': 63403,
#  'Samsung GT-I9060I': 1679,
#  'Samsung SM-T515': 2859,
#  'Samsung SM-G360M': 2990,
#  'P10': 232,
#  'Moto E (4)': 84042,
#  'Samsung SM-G925F': 1416,
#  'Samsung GT-I9300': 629,
#  'NP-752Go': 2966,
#  'G8341': 488,
#  'ONEPLUS A3003': 661,
#  'Quantum MUV UP': 249,
#  'iPhone9,4': 378697,
#  'LG-H630': 4421,
#  'GO3C': 1681,
#  'XiaoMi MI CC 9': 33,
#  'Samsung SM-J810F': 364,
#  'iPhone11,8': 377856,
#  'LG-X220': 5478,
#  'Samsung SM-C9000': 1194,
#  'Samsung SM-G3812B': 254,
#  'E_Lite': 1703,
#  'Pixel 2': 464,
#  'Samsung SM-T825': 1412,
#  'Samsung SM-G532G': 833,
#  'Lenovo L78051': 1313,
#  'iPhone12,1': 223538,
#  'Samsung SM-G975F': 249968,
#  '62S': 554,
#  'LG-D683': 351,
#  'Samsung SM-J330FN': 124,
#  'Moto G (5S)': 368239,
#  'Asus A007': 18854,
#  'LG-H990': 571,
#  'BLU DASH L': 44,
#  'MS45S': 83,
#  'Other': 14651118,
#  'Moto Z3 Play': 134201,
#  'Samsung SM-A500M': 30355,
#  'Lenovo A6020l36': 79691,
#  'M8 Pro': 68,
#  'MS50X': 8819,
#  'Asus Z01HDA': 1255,
#  'Samsung SM-A102U1': 190,
#  'Samsung SM-J600GT': 575616,
#  'Samsung SM-J730G': 358198,
#  'Samsung SM-A910F': 37083,
#  'Neffos X1 Lite': 292,
#  'CPH1909': 561,
#  'Samsung SM-J260T1': 57,
#  'XT1034': 88,
#  'Asus X01BDA': 10505,
#  'LG-H840': 4780,
#  'Samsung SM-J500H': 2382,
#  '5026J': 2744,
#  'Asus ZB500KG': 97,
#  'Samsung SM-N9750': 48,
#  'Samsung SM-P550': 842,
#  'HUAWEI Y321-U051': 139,
#  'BLU DASH X2': 87,
#  'Samsung SM-G925A': 404,
#  'Samsung GT-I9070': 78,
#  'XiaoMi MI PLAY': 11042,
#  'Samsung SM-G903M': 9663,
#  'Samsung SM-T331': 78,
#  'iPad7,5': 1777,
#  'iPad4,8': 52,
#  'Samsung SM-J737T1': 254,
#  'Samsung SM-J120M': 4510,
#  'LG-D100': 2074,
#  'Samsung SM-A307G': 157,
#  'E6833': 68,
#  'Samsung SM-G950U1': 2589,
#  'Samsung SM-G975U1': 1638,
#  'Samsung SM-T595': 2309,
#  'Samsung SM-T819': 737,
#  'Samsung SM-J260F': 6,
#  'LG-M320': 381681,
#  'Samsung SM-J250M': 84761,
#  'Asus X00RD': 29891,
#  '5033J': 8881,
#  '5010E': 14665,
#  'BLU Studio Touch': 96,
#  'LG K350': 722,
#  'Samsung SM-J330F': 94,
#  'Samsung GT-S5310C': 207,
#  'Samsung SM-J106F': 58,
#  'Positivo Next': 3,
#  'Samsung SM-G531BT': 56395,
#  'Samsung SM-N9600': 79075,
#  'Lenovo K33b36': 74458,
#  'XT1069': 16447,
#  'S31': 367,
#  'HT16': 379,
#  'XiaoMi MI 5s Plus': 1209,
#  'LG-M327': 95,
#  'Samsung SM-J500F': 162,
#  'YPY_S500': 102,
#  'Samsung GT-S7562L': 81,
#  'Samsung GT-I9515L': 10118,
#  'XiaoMi Redmi K20 Pro Premium Edition': 90,
#  'Samsung SM-A500H': 31,
#  'NX573J': 1066,
#  'S70': 171,
#  'XT1068': 12304,
#  'Samsung SM-J110M': 1935,
#  'NX551J': 321,
#  '705-G': 237,
#  'LG-M257': 82,
#  'Samsung SM-G610M': 1225247,
#  'M6T': 559,
#  'Samsung SM-A505G': 9240,
#  'ML-JI11-M7_3G_PLUS': 168,
#  'LIO+': 685,
#  'XiaoMi MI 5s': 524,
#  'Vivo 8': 45,
#  'Lenovo K51c78': 82,
#  'Samsung SM-C7010': 157,
#  'Samsung SM-G3502L': 436,
#  'iPhone6,1': 17538,
#  'Twist Metal 32GB': 1639,
#  'C2304': 147,
#  'iPad6,8': 87,
#  'JOY': 987,
#  'vivo 1716': 6,
#  'Samsung SM-J110L': 75,
#  'Samsung GT-I9195': 964,
#  'LG-D390': 42,
#  'LGMS210': 186,
#  'iPhone12,5': 111271,
#  'XiaoMi Redmi 6 Pro': 605,
#  'DUB-LX1': 665,
#  'MS50G': 15089,
#  'Asus Z00UD': 7322,
#  'Vivo XI': 2269,
#  'Samsung SM-E500M': 1405,
#  'Samsung SM-P615': 132,
#  'C1604': 140,
#  'BLU STUDIO C HD': 24,
#  'iPhone8,2': 96357,
#  'WAS-LX1': 267,
#  'victor': 144,
#  'M9 Pro': 302,
#  'Samsung SM-N950U1': 335,
#  'LG-H735': 15,
#  'Nokia 6': 3363,
#  'Samsung SM-G7102T': 574,
#  'LG-X170fTV': 979,
#  'MS45S_A6': 1270,
#  '5085J': 2252,
#  'G_Max': 3243,
#  'Smartphone DL Horizon H8': 371,
#  'CPH1803': 109,
#  'GO3C Plus': 1650,
#  'HDT-9421G': 395,
#  'You': 2693,
#  'Q06': 128,
#  'LG-K580': 10354,
#  'XiaoMi MI 6': 6964,
#  'SC-02H': 16,
#  'RNE-L23': 344,
#  'Asus Z01FD': 29,
#  'Moto G (5)': 358078,
#  'vivo 1901': 67,
#  'M10A-Lite': 166,
#  'iPad11,1': 232,
#  'Moto G5 (XT1672)': 2846,
#  'LG-M151': 32,
#  'Lenovo YB1-X90F': 16,
#  'Samsung SM-G611MT': 306078,
#  'Twist 2': 11923,
#  'Quartzo UP': 1019,
#  'XiaoMi Redmi Note 3': 1448,
#  'Lenovo B8000-F': 478,
#  'HTC Desire 550': 30,
#  'BLU Grand X LTE': 336,
#  'DASH C MUSIC': 73,
#  'XiaoMi Redmi Note 9S': 6797,
#  'Samsung GT-S7582': 55,
#  'Samsung SM-F700F': 440,
#  'LG-K420': 1085,
#  'iPad4,4': 2336,
#  'C5': 1925,
#  'iPhone4,1': 99,
#  'Samsung SM-G355M': 1798,
#  'Samsung SM-A7050': 99,
#  'LM-Q710.FGN': 4961,
#  'Lenovo Z90-7': 143,
#  'WAS-LX3': 176,
#  'Samsung SM-G6000': 44,
#  'Samsung SM-G930F': 128283,
#  'iPhone10,2': 66386,
#  'GOME_U9': 754,
#  'XiaoMi Redmi K30': 19,
#  'Samsung SM-A300M': 7001,
#  'Asus X00ADA': 1825,
#  'ZB500KG': 673,
#  'Lenovo A6020a40': 3032,
#  'MS60F_PLUS': 1342,
#  'Nokia 6.1 Plus': 1730,
#  'Lenovo L78011': 228,
#  'fnac 5': 68,
#  'Samsung SM-A405FN': 1700,
#  'Asus X00BD': 196,
#  'LG M320': 275,
#  'HTC 10': 75,
#  'Samsung SM-N7502': 209,
#  'Tablet_DL_2820': 173,
#  'Lenovo L38041': 1851,
#  'Samsung SM-G965U1': 1728,
#  'LG-H818': 4830,
#  'Samsung SM-G928G': 4855,
#  'NX612J': 136,
#  'ENERGY XL': 65,
#  'Samsung SM-J320M': 134113,
#  'iPhone5,4': 6114,
#  'Lenovo K50-t5': 330,
#  'vernee_M5': 433,
#  'LND-AL30': 309,
#  'Lenovo K10e70': 188,
#  'Che2-L11': 59,
#  'Samsung SM-G920T': 58,
#  'iPhone8,4': 109386,
#  'Asus I001DB': 380,
#  'PTB7QSG_3G': 111,
#  'Samsung GT-S7582L': 4404,
#  'RNE-L22': 474,
#  'LG M250': 1160,
#  'Samsung GT-S6792L': 34,
#  'R2 LTE': 700,
#  'Samsung SM-A310M': 6609,
#  'Samsung SM-N960U1': 296,
#  'Samsung SM-T560': 164,
#  'GO 2': 95,
#  'Samsung SM-T380': 5,
#  'Quantum Go': 1740,
#  'Samsung SM-N975U': 51,
#  'Lenovo L18021': 342,
#  'Samsung SM-G900FD': 196,
#  'Samsung SM-G935L': 18,
#  'Samsung SM-G955N': 208,
#  'Samsung KDDI': 18,
#  'Asus Z017DC': 18016,
#  'XT1039': 259,
#  'Samsung SM-J320H': 1428,
#  'LG-H540': 4862,
#  'Samsung SM-T725': 1018,
#  'LG-M210': 22,
#  'LG-E425f': 67,
#  'Asus Z01KDA': 1490,
#  'XiaoMi Redmi Note 7 Pro': 1175,
#  'C6503': 55,
#  'LG-D125': 1116,
#  'LG-H340': 580,
#  'iPad8,7': 161,
#  'Nokia 7': 61,
#  'Samsung SM-J700H': 2067,
#  'MS40S': 1144,
#  'MS60Z': 1136,
#  'LG-D724': 344,
#  'Samsung SM-J415F': 93,
#  'Vivo 5R': 63,
#  'VIE-L09': 64,
#  'Samsung SM-T280': 4810,
#  'Asus Z01RD': 12654,
#  'M9-3G': 435,
#  'Samsung SM-G531M': 8637,
#  'Samsung SM-G891A': 317,
#  'Samsung SM-N920G': 2662,
#  'G6 Plus': 25,
#  'XT1635-02': 49188,
#  'Lenovo A1010a20': 1066,
#  'Samsung SM-N970F': 26783,
#  'Lenovo L58041': 330,
#  'BLU STUDIO G2': 636,
#  'XT1021': 136,
#  'VKY-L29': 96,
#  'Lenovo L78032': 1073,
#  'BLU ADVANCE 4.0 L2': 1420,
#  'GO5E': 5727,
#  'Samsung SM-G318ML': 80,
#  'Samsung SM-G960W': 460,
#  'XiaoMi Redmi 3': 409,
#  'Samsung SM-J200H': 859,
#  'LM-X410.F': 286957,
#  'Studio View XL': 370,
#  'D5322': 480,
#  'S10_Pro': 359,
#  'A3_Pro': 74,
#  'Samsung SM-A705MN': 259297,
#  'F8331': 204,
#  'LG-D805': 140,
#  'Samsung SM-G975U': 495,
#  'iPod7,1': 2018,
#  'K10': 19,
#  'Lenovo P2a42': 14,
#  'Le X526': 172,
#  'iPad8,1': 259,
#  'Samsung SM-G570F': 775,
#  'H3223': 575,
#  'PRA-LX1': 297,
#  'Samsung SM-G920A': 207,
#  'dolphin': 107,
#  'Samsung SM-A260G': 879,
#  'Samsung GT-S6810B': 35,
#  'Samsung SM-G955F': 146520,
#  'Asus X00DDB': 999,
#  'Asus X008DC': 72,
#  'XT1663': 30,
#  'LG-H422': 5419,
#  'Samsung SM-G955U1': 1377,
#  'LG-X240': 12120,
#  'Asus I01WD': 6630,
#  'Samsung GT-I8552': 21,
#  'LG-K500': 6037,
#  'Tablet_DL_4010': 194,
#  'TP601B': 46,
#  'LG-E615f': 159,
#  'Generic Smartphone': 40317411,
#  'Samsung SM-G973F': 153723,
#  'Samsung SM-G960U1': 1227,
#  'iPad7,11': 389,
#  'iPad4,7': 13,
#  'Lenovo TB-X705F': 5,
#  'Twist Mini': 15444,
#  'HT37Pro': 106,
#  'D2114': 398,
#  'Samsung SM-T285M': 13812,
#  'Samsung SM-G960F': 4928,
#  'Advance 4.0 L3': 377,
#  'Samsung SM-J600F': 56,
#  'LG-E475f': 36,
#  'LG-AS330': 21,
#  'C6843': 11,
#  'Samsung SM-J737U': 38,
#  'Samsung SM-A505GT': 629962,
#  'Samsung SM-A315G': 3557,
#  'Samsung GT-I9300I': 4346,
#  'Asus T00J': 417,
#  'D6633': 634,
#  'Asus X00DD': 180,
#  'SGP551': 536,
#  'Samsung SM-A310F': 172,
#  'Samsung SM-N950F': 47743,
#  'GOME 2017M27A': 1682,
#  'Samsung GT-S7275B': 232,
#  'K10000 Pro': 14,
#  'Samsung SM-A605FN': 798,
#  'Pixel C': 260,
#  'Samsung SM-T111M': 677,
#  'Asus X00TD': 711,
#  'XiaoMi MI 9 Transparent Edition': 161,
#  'Samsung SM-J610F': 133,
#  'LG-H910': 73,
#  'XT1635-03': 80,
#  'Moto G4 Plus': 96,
#  'Samsung SM-G900A': 30,
#  'LG-H870': 14397,
#  'Samsung SM-P355M': 1451,
#  '4055J': 1728,
#  'Positivo US2070': 35,
#  'exbom': 425,
#  'E2306': 99,
#  'Samsung GT-I9105P': 86,
#  'Samsung SM-G975W': 683,
#  'Samsung SM-J200BT': 48352,
#  'XiaoMi Redmi Note 8T': 41903,
#  'Samsung SM-J410F': 490,
#  '5046J': 937,
#  'Lenovo L38012': 467,
#  'F8332': 82,
#  'FRD-AL10': 131,
#  'iPhone9,1': 97042,
#  'Samsung SM-G800H': 9683,
#  'G3116': 1673,
#  'E6603': 261,
#  'Mi A1': 65,
#  'MZ-M5c': 297,
#  'Samsung SM-J410G': 581226,
#  'Samsung SM-G965F': 4924,
#  'LG-D690n': 7821,
#  'G': 1316,
#  'Samsung SM-G935A': 376,
#  'Samsung SM-G928F': 267,
#  'Samsung SM-N975U1': 79,
#  'Le X522': 652,
#  'Samsung SM-T510': 2703,
#  'Samsung SM-G900P': 1750,
#  'HP 7.1': 371,
#  'iPad11,3': 111,
#  'Samsung SM-T385M': 1830,
#  'BLL-L22': 42,
#  'Samsung SM-A9000': 89,
#  'Life One X2': 21,
#  'Samsung SM-G9650': 296148,
#  'Samsung SM-G610F': 20518,
#  'Samsung SM-N910C': 3935,
#  'BV9500': 42,
#  'Samsung SM-A605GN': 74419,
#  'LG-K430': 362463,
#  'iPhone7,1': 43379,
#  'Samsung GT-I9063T': 4805,
#  'XiaoMi MI MAX 3': 10312,
#  'XiaoMi Redmi 4A': 3299,
#  'Lenovo K53a48': 1543,
#  'Samsung SM-J106B': 1391,
#  'Samsung SM-G892A': 78,
#  'Samsung SM-A307GN': 39,
#  'R1 PLUS': 197,
#  'Samsung GT-S6313T': 349,
#  'Samsung SAMSUNG SM-N9005': 37,
#  'LG-V400': 4,
#  'Asus X00DDA': 13139,
#  'G3312': 355,
#  'Lenovo K8 Plus': 8176,
#  'Samsung GT-N7000': 197,
#  'Moto G': 101,
#  'LG-K200': 41869,
#  '5199I': 900,
#  'Motorola MZ608': 65,
#  'XT1650': 4705,
#  'BBD100-2': 675,
#  'Samsung SM-T700': 101,
#  'ATU-LX3': 39,
#  'Z831': 72,
#  'Samsung SM-M305M': 62999,
#  'XiaoMi Redmi 4X': 3650,
#  'XiaoMi Redmi Note 4X': 923,
#  'Samsung SAMSUNG-SM-J320A': 370,
#  'XT1040': 1669,
#  'Asus Z00LD': 2728,
#  'Samsung SM-N920S': 1139,
#  'LG-H873': 639,
#  'D2403': 491,
#  'Samsung GT-N7105T': 37,
#  'G4': 96,
#  'XiaoMi MI 8 Pro': 8354,
#  'Samsung GT-I9295': 668,
#  'iPad5,2': 147,
#  'BLA-L29': 637,
#  'Samsung SM-T835': 88,
#  'Asus X00ID': 18342,
#  'C NOTE 2': 705,
#  'E6633': 2577,
#  'Samsung SM-J720M': 6752,
#  'MZ-meizu C9': 70,
#  'Kindle': 1313,
#  'Samsung SM-G970U1': 96,
#  'Lenovo A6020a46': 172,
#  'Lenovo TB-8703F': 137,
#  'E6683': 52,
#  'ELUGA_A3_Pro': 302,
#  'Samsung SM-J500FN': 37,
#  'Samsung SM-T805M': 570,
#  'Asus X017D': 15434,
#  'Samsung GT-N5100': 162,
#  'Samsung SM-P605M': 43,
#  'XT1092': 93,
#  'XiaoMi MI MAX 2': 2172,
#  'Microsoft Virtual': 68,
#  'ML-SO-M7_3G_PLUS': 427,
#  'Nokia 3': 67,
#  'vivo NEX A': 472,
#  '9008N': 6670,
#  'XiaoMi MI 9 SE': 4252,
#  'XiaoMi MI CC9 Pro': 245,
#  '7048A': 13,
#  'C8': 100,
#  'NX569J': 155,
#  'LG-D175f': 1187,
#  'LG-D855': 515,
#  'Generic Feature Phone': 67,
#  'S9+': 392,
#  'TX92': 80,
#  'Lenovo P1c58': 332,
#  'moto g(6) play': 74154,
#  'PlayStation 4': 682,
#  'NP-852': 64,
#  'Samsung SM-A6060': 233,
#  'iPad4,1': 798,
#  'Z2': 119,
#  'Samsung SM-G930A': 2006,
#  'G8232': 49,
#  'LG-E989': 389,
#  'moto e5 plus': 59856,
#  'Twist (2018)': 13396,
#  'XT1580': 2871,
#  'Lumia 640': 281,
#  'Inettv': 45,
#  'MHA-L29': 6,
#  'Samsung SM-G955W': 48,
#  'Samsung SM-J120H': 87896,
#  'RNE-L21': 415,
#  'LM-G710': 455,
#  ...}

# %%
df_os = df.groupBy('os_family').count().toPandas()

# %%
df_os
# Out:
#          os_family     count
# 0       Windows 10   7487631
# 1        Windows 8     72571
# 2              iOS   9857804
# 3      Windows 8.1    514360
# 4            Linux    414139
# 5            Other   7902683
# 6           Fedora      2867
# 7   Windows Mobile        83
# 8    Windows Vista      6114
# 9        Chrome OS     18600
# 10          Ubuntu     51097
# 11   Windows Phone      3342
# 12         FreeBSD       215
# 13         Android  72427957
# 14      Windows XP     25447
# 15       Windows 7   3022648
# 16        Mac OS X    513988

# %%
import pandas as pd
list_os = df_os.os_family.values
list_os_values =  df_os['count'].values

# %%
dict_os = {}
for i in range(len(list_os)):
  dict_os.update({list_os[i]: list_os_values[i]})
dict_os
# Out:
# {'Android': 72427957,
#  'Chrome OS': 18600,
#  'Fedora': 2867,
#  'FreeBSD': 215,
#  'Linux': 414139,
#  'Mac OS X': 513988,
#  'Other': 7902683,
#  'Ubuntu': 51097,
#  'Windows 10': 7487631,
#  'Windows 7': 3022648,
#  'Windows 8': 72571,
#  'Windows 8.1': 514360,
#  'Windows Mobile': 83,
#  'Windows Phone': 3342,
#  'Windows Vista': 6114,
#  'Windows XP': 25447,
#  'iOS': 9857804}

# %% [markdown]
# # **Resultado Etapa 2**
# Condenso aqui a quantidade de sessões únicas que ocorreram em cada Browser, Sistema Operacional e Dispositivo dentro de todo o conjunto de dados no formato solicitado

# %%
dict_etapa2 = {}
dict_etapa2.update({"browser_family": dict_browser,"os_family": dict_os, "device_family": dict_devices})
dict_etapa2
# Out:
# {'browser_family': {'AdsBot-Google': 113649,
#   'Amazon Silk': 1313,
#   'Android': 404,
#   'AppleMail': 751,
#   'Applebot': 73,
#   'BingPreview': 334,
#   'Chrome': 11206495,
#   'Chrome Mobile': 51526442,
#   'Chrome Mobile iOS': 690819,
#   'Chromium': 6110,
#   'Edge': 85378,
#   'Edge Mobile': 3274,
#   'Facebook': 17789908,
#   'Firefox': 763711,
#   'Firefox Mobile': 125298,
#   'Firefox iOS': 8097,
#   'GooglePlusBot': 139,
#   'Googlebot': 7978243,
#   'IE': 104,
#   'IE Mobile': 68,
#   'Investment Crawler': 3,
#   'Maxthon': 193,
#   'Mobile Safari': 4707652,
#   'Mobile Safari UIWebView': 4365301,
#   'Opera': 174649,
#   'Opera Mini': 223,
#   'Opera Mobile': 75357,
#   'Other': 2489787,
#   'Pale Moon (Firefox Variant)': 150,
#   'PetalBot': 1155,
#   'Pinterest': 62,
#   'Puffin': 2400,
#   'SMTBot': 284,
#   'Safari': 161855,
#   'SeaMonkey': 25,
#   'UC Browser': 38617,
#   'Vivaldi': 1257,
#   'Yahoo! Slurp': 72,
#   'Yandex Browser': 1894},
#  'device_family': {'iPhone11,2': 56001,
#   'MS50L_4G': 1189,
#   'XiaoMi Redmi 7': 62385,
#   'XiaoMi Redmi Go': 23643,
#   'KYY23': 140,
#   'Samsung SM-G970N': 406,
#   'iPad6,12': 44,
#   'Samsung SM-A730F': 74534,
#   'ML-TI-MS80': 1455,
#   'Samsung SM-G770F': 2166,
#   'XT1225': 1983,
#   'Pixel 2 XL': 32,
#   'KING 7': 37,
#   'MZ-MX4': 6,
#   'Samsung SM-J260M': 372689,
#   'LG-D337': 53540,
#   '5159J': 10077,
#   'Lenovo K53b36': 39969,
#   'Samsung SM-T865': 321,
#   'LG-V480': 42,
#   'XiaoMi Redmi S2': 28957,
#   'ZE553KL': 7205,
#   'S60': 147,
#   'C6': 775,
#   'M7_3G_PLUS': 1368,
#   'BLU NEO X MINI': 177,
#   'XT621': 25,
#   'Samsung SM-T705M': 436,
#   'Grand X': 648,
#   'XT1585': 77,
#   'Samsung SM-T285YD': 463,
#   'Samsung SM-T330': 27,
#   'Nokia 2': 3076,
#   'MZ-M5 Note': 15,
#   'Samsung SM-G935T': 3,
#   'iPhone6,2': 80690,
#   'LG-H502': 4487,
#   'Samsung SM-N960F': 5147,
#   'C6943': 1452,
#   'Samsung GT-S7583T': 1052,
#   'Moto X4': 26,
#   'ZTE Blade L5': 287,
#   'XiaoMi Redmi 6': 54770,
#   'LG-H860': 1725,
#   'LG-H342': 4611,
#   'MS55M': 646,
#   'Samsung SM-N976U': 669,
#   'MX9-4K': 76,
#   'Samsung SM-A507FN': 48,
#   'HTC 10 evo': 41,
#   'Spider': 8092463,
#   'Z Play': 523,
#   'Sky': 1861,
#   'Samsung SM-T561M': 179,
#   'Samsung SM-G920V': 1314,
#   'MN4A2ZP/A': 261,
#   'Lenovo K10a40': 32925,
#   'NX591J': 734,
#   'Samsung SM-A700FD': 6433,
#   'Samsung SM-A202F': 1195,
#   'Samsung SM-T110': 272,
#   'Meizu M6s': 178,
#   'U2': 143,
#   'Samsung SM-G950F': 239451,
#   'Samsung SM-G935U': 190,
#   'Samsung SM-G960U': 1418,
#   'LG-H831': 192,
#   'TV BOX': 96,
#   'Samsung SM-G530T': 409,
#   'Archos Core 50 4G': 774,
#   'Samsung SM-G316M': 282,
#   'LG-H221': 839,
#   'iPad': 44369,
#   'Moto G (5S) Plus': 368610,
#   'MotoE2(4G-LTE)': 5116,
#   '5085N': 5142,
#   'Samsung SM-G9750': 135,
#   'Moto G (4)': 158121,
#   'G_Pro': 1833,
#   'G3311': 132,
#   'Lenovo TB2-X30F': 573,
#   'X21 Plus': 74,
#   'D5803': 17,
#   'LG-H931': 68,
#   'Samsung SM-J701MT': 417172,
#   'Samsung SM-A750G': 177630,
#   'Positivo Twist 4G': 5722,
#   'Samsung SM-G973U1': 982,
#   'M10A': 43,
#   'Lumia 950': 56,
#   'iPad3,5': 735,
#   'Samsung SM-N950U': 1089,
#   'Samsung SM-G3502T': 888,
#   '5016J': 973,
#   'D5833': 220,
#   'Samsung SM-A530F': 122161,
#   'XiaoMi Redmi 8': 55127,
#   'Grand XL': 167,
#   '91S': 43,
#   'Samsung SM-G850F': 330,
#   'Samsung SM-T311': 30,
#   'Samsung SM-A520F': 123547,
#   'Samsung SM-N935F': 281,
#   'Vivo 5 Mini': 253,
#   'HS007C': 70,
#   'XiaoMi MI 9': 74411,
#   'Asus X00TDB': 61365,
#   'Positivo Slim': 1294,
#   'VFD 620': 130,
#   'Samsung SM-A750GN': 337,
#   'XT1563': 782,
#   'Samsung SM-G9730': 23,
#   'LEX651': 216,
#   'Samsung SM-J250F': 103,
#   'iPhone10,4': 322985,
#   'LG-D385': 2031,
#   'You L': 848,
#   'Samsung SM-J415FN': 478,
#   'BBC100-1': 19,
#   'Moto E': 650,
#   'Asus I001DD': 165,
#   'Samsung SM-J727U': 118,
#   'S10': 303,
#   'moto g6 plus': 157,
#   'F': 13276,
#   'XiaoMi Redmi Note 5': 47527,
#   'iPhone9,2': 72248,
#   'Lenovo A2016b30': 36655,
#   'PHONEMAX_Saturn': 99,
#   'DUB-LX3': 268,
#   'M7sLite': 213,
#   'X50A': 84,
#   'INE-LX1': 134,
#   'Archos 60 Platinum': 193,
#   'iPad3,3': 40,
#   'SGP311': 77,
#   'Samsung SM-J510FN': 104,
#   'iPhone7,2': 227841,
#   'Samsung SM-G600FY': 84674,
#   'MotoG3-TE': 4318,
#   'MIX 2': 618,
#   'E6653': 477,
#   'F5122': 1209,
#   'STV100-3': 887,
#   'moto g(6) plus': 13940,
#   'Nokia 7 plus': 112,
#   'LG-H326': 4368,
#   'Samsung SM-N960N': 1161,
#   'Samsung SM-G900F': 662,
#   'Platinum_5.0M': 169,
#   'Kingbox': 161,
#   'iPhone10,6': 178697,
#   'Positivo Twist M': 3378,
#   'Samsung SM-P585M': 1350,
#   'Samsung SM-P555M': 686,
#   'Samsung SM-A305FN': 85,
#   'ML-WI-M9-3G': 23,
#   'Samsung SM-G532M': 196982,
#   'LG-H815': 2720,
#   'Asus X00LDA': 12295,
#   'Samsung SM-J701F': 1961,
#   'Samsung SM-N910A': 1221,
#   'INE-LX2': 69,
#   'Samsung SM-J727T': 88,
#   'Samsung GT-S5303B': 87,
#   'Le X520': 5,
#   'XiaoMi MI 8': 23202,
#   'XT1025': 1234,
#   'Lenovo A7600-F': 33,
#   'XT1609': 50,
#   'D6643': 63,
#   'Samsung SM-G900H': 28,
#   'Nexus 5': 494614,
#   'Samsung SM-G935F': 137698,
#   'Samsung SM-T295': 2953,
#   'Armor_3': 5,
#   'MS80X': 1747,
#   'Samsung GT-I9505G': 32,
#   'HUAWEI LUA-U23': 49,
#   'T96 Mars': 40,
#   'MYA-L11': 465,
#   'Samsung GT-I8200L': 231,
#   'Asus Z00XS': 841,
#   'Samsung SM-P200': 99,
#   'Samsung SM-A920F': 90733,
#   'Samsung GT-I8190L': 619,
#   'Samsung GT-I8262B': 442,
#   'Samsung SM-N960U': 489,
#   'Samsung GT-P5210': 22,
#   'Twist Tab': 56,
#   'E6553': 251,
#   'BV8000Pro': 152,
#   'M5c': 289,
#   'Advance L4': 918,
#   'Nokia 2.3': 139,
#   'KFAUWI': 72,
#   'iPad7,3': 59,
#   'NV6': 18,
#   'LM-X210': 213072,
#   'XiaoMi Redmi Note 6 Pro': 65299,
#   'Samsung SM-G920I': 33530,
#   'Samsung SM-T555': 1990,
#   'Samsung GT-S7273T': 990,
#   'S8': 373,
#   'TVBOX': 195,
#   'GO3E': 5324,
#   'Huawei Browser': 1192,
#   '4009E': 134,
#   'Samsung SM-T585': 1916,
#   'LEX720': 183,
#   'M5s': 51,
#   'Samsung SM-J320F': 148,
#   'LG-K500n': 9,
#   'Samsung SM-G530H': 6556,
#   '1001-G Go': 2338,
#   'Armor_6': 222,
#   'MS50M': 436,
#   'Samsung SM-P205': 186,
#   'Power 3S': 63,
#   'Samsung GT-S7560M': 56,
#   'LG-K220': 71339,
#   'Samsung SM-G316ML': 265,
#   'S30': 194,
#   'S60Lite': 331,
#   'Samsung GT-I9082': 250,
#   'LG-D325': 2213,
#   'Samsung SM-A115M': 268,
#   '5017E': 127,
#   'Samsung SM-G928A': 109,
#   'Z971': 313,
#   'Samsung SM-J510MN': 123953,
#   'Samsung SM-J105M': 24233,
#   'XiaoMi Redmi 5': 4904,
#   'Samsung SM-J100M': 548,
#   'SUPER': 11,
#   'F_Pro': 1242,
#   'Samsung SM-G930T': 96,
#   'XiaoMi Redmi Note 5A': 332,
#   'Samsung SM-G6100': 923,
#   'Twist 2 Go': 115,
#   'XiaoMi Redmi K20': 311,
#   'Samsung SM-G130BU': 51,
#   'Asus X018D': 11949,
#   'XiaoMi Redmi Note 4': 14135,
#   'Samsung SM-G900M': 20158,
#   'LG-H870DS': 452,
#   'Samsung GT-P5200': 330,
#   'Samsung SM-G970X': 423,
#   'Le X620': 57,
#   'Samsung SM-G890A': 8,
#   'LG-K520': 107,
#   'Samsung SM-M205M': 51437,
#   'LM-X420': 15601,
#   'Samsung SM-N975F': 73657,
#   'Samsung SM-G955U': 1661,
#   'Samsung SM-T530': 15,
#   'HDT-7427G': 519,
#   'Samsung SM-A305GN': 90,
#   'Nokia 3.1 Plus': 152,
#   'X206': 47,
#   'LG-H930': 54,
#   'Positivo Twist S': 3271,
#   'MS50L': 29032,
#   'DUA-L22': 486,
#   'LG-X210': 1600,
#   'iPhone12,8': 2602,
#   'Samsung SM-A305G': 2087,
#   'K3': 261,
#   'Samsung SM-G9600': 274191,
#   'LG-M320G': 1,
#   'iPhone': 5372658,
#   'Samsung SM-A750FN': 236,
#   'Samsung SM-J320FN': 415,
#   'PTB7PAP_PTB7PAB_PTB7PAR': 252,
#   'D2212': 108,
#   'BLL-L23': 96,
#   'XT1799-2': 534,
#   'Samsung SM-A305GT': 717587,
#   'Asus Z00YD': 1725,
#   'LG-TP260': 46,
#   'Moto G 2014': 31,
#   'LG-D157f': 775,
#   'Samsung SM-J326AZ': 1055,
#   'Samsung SM-J330G': 995,
#   'E': 4072,
#   'iPhone5,1': 8924,
#   'Samsung SM-N915T': 554,
#   'Samsung SM-G900MD': 4806,
#   'XiaoMi MI A3': 113,
#   'HTC One M9': 2334,
#   'Asus X00QD': 67892,
#   '8050E': 17607,
#   'MONDIAL': 138,
#   'S430 Positivo Twist Mini': 1381,
#   'JSN-L21': 760,
#   'LG-H870S': 134,
#   'Lenovo K33a42': 386,
#   '5060D': 1,
#   'Samsung SM-J260MU': 4278,
#   'HT-705XS': 24,
#   'Samsung SM-J700T1': 518,
#   'Samsung SM-J106M': 136,
#   'iPhone11,6': 137381,
#   'LG-D410': 4228,
#   'GIONEE S11 lite': 38,
#   'LG-E435f': 392,
#   'iPad8,3': 116,
#   'Samsung SM-A600FN': 278,
#   'Samsung SM-J530F': 125,
#   'Nexus 5X': 650,
#   'iPhone10,1': 35516,
#   'Samsung GT-I9192': 18864,
#   'Samsung SM-G930U': 2282,
#   '4017F': 2451,
#   'XT1572': 933,
#   '2014819': 803,
#   'LG-E977': 118,
#   'Samsung SM-N9700': 63,
#   'Meizu M6': 115,
#   'LG-P705': 87,
#   'moto e5 play': 205677,
#   'XiaoMi Redmi Note 5A Prime': 2331,
#   'Moto X Play': 15157,
#   'POCOPHONE F1': 330,
#   'Twist Metal': 1513,
#   'XT1058': 562,
#   'Asus FBBD': 2900,
#   'XT1078': 1915,
#   'MS60X': 1466,
#   'E5563': 414,
#   'C103': 61,
#   'iPhone9,3': 594196,
#   'iPad3,4': 776,
#   'Samsung SM-J610FN': 437,
#   'Asus Z017DA': 637,
#   'Bluboo_S8_plus': 97,
#   'C5303': 32,
#   'S420': 110,
#   'Samsung SM-J200G': 134,
#   'moto e5': 166041,
#   'Lenovo K520': 1708,
#   'Moto G5S (XT1792)': 37,
#   'Samsung GT-I9200': 97,
#   'Samsung SM-A600GN': 98,
#   'Samsung SM-A715F': 76628,
#   'iPad7,6': 98,
#   'Asus Z00VD': 1063,
#   'LG-H222': 7967,
#   'Samsung GT-S5310B': 905,
#   '6039J': 211,
#   'Lenovo L38111': 302,
#   'STV-2000': 57,
#   'Samsung SM-J105B': 135938,
#   'Samsung SM-J730GM': 6051,
#   'Vivo XI+': 544,
#   'MS60F': 4428,
#   'MS50S': 104,
#   'itel A15': 70,
#   'Asus Z012DA': 164,
#   'LG-V500': 61,
#   'X23': 81,
#   'HUAWEI LYO-L21': 76,
#   'Moto G7 Plus': 2,
#   'Samsung GT-I8552B': 9405,
#   'Samsung SM-A105FN': 1622,
#   'HTC One M8': 209,
#   'LGMP260': 1518,
#   'G3313': 163,
#   'Samsung SM-A205GN': 337,
#   'LG-M700': 158408,
#   'Samsung SM-J200M': 21233,
#   'LG-H820': 154,
#   'BLU ENERGY DIAMOND': 96,
#   'MZ-Meizu M6s': 28,
#   'MYA-L23': 660,
#   'Samsung SM-G988U1': 18,
#   'LG-M150': 32,
#   'Tablet_DL_2810': 13,
#   'Samsung SM-G950U': 1767,
#   'Quantum You 2': 821,
#   '71S': 500,
#   '6060S': 71,
#   'Neffos C5': 303,
#   'XiaoMi MI 8 Lite': 224838,
#   'Samsung SM-G985F': 14687,
#   'MS40G': 7101,
#   'Asus Z00AD': 9642,
#   'iPhone5,2': 1219,
#   'Samsung GT-P3100': 146,
#   'vivo 1805': 6,
#   'LG-M400': 39875,
#   'Asus X017DA': 31090,
#   '4034E': 15214,
#   'Samsung SM-J710F': 1738,
#   'Samsung GT-S6293T': 5817,
#   'LG-H918': 90,
#   'iPad7,4': 55,
#   'XiaoMi Redmi Pro': 180,
#   'Samsung SM-G903F': 131,
#   'XT1706': 83,
#   'Samsung SM-T715Y': 158,
#   'Samsung SM-G970U': 74,
#   'Samsung SM-J400M': 321733,
#   'Samsung SM-J727T1': 147,
#   '9008J': 3824,
#   'Samsung SM-A102U': 538,
#   'ZUK Z2121': 341,
#   'XT1079': 1681,
#   'Samsung SM-G920F': 2297,
#   'VF-1397': 64,
#   'Lumia 435': 45,
#   'Moto C Plus': 155664,
#   'XT1032': 5631,
#   'Samsung SM-J700F': 3549,
#   'Samsung SM-C5010': 497,
#   'LG-H830': 187,
#   'Tablet_DL_2811': 1198,
#   'LG-E470f': 211,
#   'moto g7 plus': 114,
#   'Samsung SM-J415G': 480652,
#   'Lenovo K33a48': 5610,
#   'Asus X013D': 12506,
#   'MUV': 2292,
#   'C2004': 16,
#   'Twist XL': 2433,
#   'M7-4G': 1344,
#   'LG-K428': 28,
#   'Samsung SM-A107F': 483,
#   'LG-D285': 189,
#   '4028E': 27,
#   'Moto Z2 Play': 193927,
#   'Samsung SM-G988B': 2760,
#   'Samsung SM-J120AZ': 71,
#   'Samsung SM-G611M': 2637,
#   'Lenovo TB-X304F': 174,
#   'Samsung SM-T580': 122,
#   'XiaoMi Redmi 8A': 41738,
#   '4009I': 73,
#   'Grand M': 79,
#   'XT1064': 247,
#   'Samsung SM-A605G': 33,
#   'C5 2019': 10,
#   'LG-K410': 3338,
#   'Lenovo A1000': 518,
#   'D6603': 1206,
#   'Samsung SM-C7000': 159,
#   'LG-E455': 281,
#   'TRT-L53': 506,
#   'Asus X00HD': 11342,
#   'LG-H522': 7078,
#   'N5L': 54,
#   'XiaoMi Redmi 4': 239,
#   'F3313': 1241,
#   'Samsung SM-A920X': 28,
#   'Asus X018DC': 23,
#   'Samsung SM-G7102': 49,
#   'Life One X2 Mini': 80,
#   'Samsung GT-I9515': 154,
#   'Samsung SM-N770F': 6472,
#   'Samsung SM-J3110': 353,
#   'Samsung SM-A217M': 53,
#   'D6543': 1536,
#   'Asus X01AD': 300,
#   'NX563J': 305,
#   'E5343': 194,
#   'G011A': 55,
#   'Plus E': 36,
#   'Samsung SM-G925I': 23667,
#   'G3226': 2945,
#   'iPad4,2': 480,
#   'LG-H870V': 97,
#   'Asus Z00A': 252,
#   'Samsung SM-J3119S': 37,
#   'PRA-LX3': 9,
#   'LG-D295': 1472,
#   'iPad5,3': 620,
#   '5049E': 319,
#   'Lenovo TB3-X70F': 95,
#   'D2306': 126,
#   'Asus Z011D': 5497,
#   'Z2 Plus': 47,
#   'XT1662': 315,
#   'iPhone5,3': 307,
#   'DIG-L03': 43,
#   'XiaoMi MI 6X': 901,
#   'Samsung SM-A205G': 932514,
#   'XT1097': 8852,
#   'G3426': 1278,
#   'Samsung SM-G110B': 223,
#   'BLU DASH M2': 420,
#   'Samsung SM-J810Y': 103,
#   'Samsung SM-J327W': 44,
#   'Samsung SM-G850M': 153,
#   'Samsung SM-T285': 6,
#   'Advance 4.0M': 426,
#   'Asus Z017D': 859,
#   'M7S_LITE': 283,
#   'Mi MIX 2': 53,
#   'D2243': 115,
#   'Aquaris X Pro': 218,
#   'MS45S_A6_Teen': 102,
#   'Asus X014D': 587,
#   'Samsung SM-G925P': 21,
#   'Archos Access 50 Color 3G': 279,
#   'Le X820': 156,
#   'Samsung SM-G530A': 127,
#   'iPhone10,3': 63403,
#   'Samsung GT-I9060I': 1679,
#   'Samsung SM-T515': 2859,
#   'Samsung SM-G360M': 2990,
#   'P10': 232,
#   'Moto E (4)': 84042,
#   'Samsung SM-G925F': 1416,
#   'Samsung GT-I9300': 629,
#   'NP-752Go': 2966,
#   'G8341': 488,
#   'ONEPLUS A3003': 661,
#   'Quantum MUV UP': 249,
#   'iPhone9,4': 378697,
#   'LG-H630': 4421,
#   'GO3C': 1681,
#   'XiaoMi MI CC 9': 33,
#   'Samsung SM-J810F': 364,
#   'iPhone11,8': 377856,
#   'LG-X220': 5478,
#   'Samsung SM-C9000': 1194,
#   'Samsung SM-G3812B': 254,
#   'E_Lite': 1703,
#   'Pixel 2': 464,
#   'Samsung SM-T825': 1412,
#   'Samsung SM-G532G': 833,
#   'Lenovo L78051': 1313,
#   'iPhone12,1': 223538,
#   'Samsung SM-G975F': 249968,
#   '62S': 554,
#   'LG-D683': 351,
#   'Samsung SM-J330FN': 124,
#   'Moto G (5S)': 368239,
#   'Asus A007': 18854,
#   'LG-H990': 571,
#   'BLU DASH L': 44,
#   'MS45S': 83,
#   'Other': 14651118,
#   'Moto Z3 Play': 134201,
#   'Samsung SM-A500M': 30355,
#   'Lenovo A6020l36': 79691,
#   'M8 Pro': 68,
#   'MS50X': 8819,
#   'Asus Z01HDA': 1255,
#   'Samsung SM-A102U1': 190,
#   'Samsung SM-J600GT': 575616,
#   'Samsung SM-J730G': 358198,
#   'Samsung SM-A910F': 37083,
#   'Neffos X1 Lite': 292,
#   'CPH1909': 561,
#   'Samsung SM-J260T1': 57,
#   'XT1034': 88,
#   'Asus X01BDA': 10505,
#   'LG-H840': 4780,
#   'Samsung SM-J500H': 2382,
#   '5026J': 2744,
#   'Asus ZB500KG': 97,
#   'Samsung SM-N9750': 48,
#   'Samsung SM-P550': 842,
#   'HUAWEI Y321-U051': 139,
#   'BLU DASH X2': 87,
#   'Samsung SM-G925A': 404,
#   'Samsung GT-I9070': 78,
#   'XiaoMi MI PLAY': 11042,
#   'Samsung SM-G903M': 9663,
#   'Samsung SM-T331': 78,
#   'iPad7,5': 1777,
#   'iPad4,8': 52,
#   'Samsung SM-J737T1': 254,
#   'Samsung SM-J120M': 4510,
#   'LG-D100': 2074,
#   'Samsung SM-A307G': 157,
#   'E6833': 68,
#   'Samsung SM-G950U1': 2589,
#   'Samsung SM-G975U1': 1638,
#   'Samsung SM-T595': 2309,
#   'Samsung SM-T819': 737,
#   'Samsung SM-J260F': 6,
#   'LG-M320': 381681,
#   'Samsung SM-J250M': 84761,
#   'Asus X00RD': 29891,
#   '5033J': 8881,
#   '5010E': 14665,
#   'BLU Studio Touch': 96,
#   'LG K350': 722,
#   'Samsung SM-J330F': 94,
#   'Samsung GT-S5310C': 207,
#   'Samsung SM-J106F': 58,
#   'Positivo Next': 3,
#   'Samsung SM-G531BT': 56395,
#   'Samsung SM-N9600': 79075,
#   'Lenovo K33b36': 74458,
#   'XT1069': 16447,
#   'S31': 367,
#   'HT16': 379,
#   'XiaoMi MI 5s Plus': 1209,
#   'LG-M327': 95,
#   'Samsung SM-J500F': 162,
#   'YPY_S500': 102,
#   'Samsung GT-S7562L': 81,
#   'Samsung GT-I9515L': 10118,
#   'XiaoMi Redmi K20 Pro Premium Edition': 90,
#   'Samsung SM-A500H': 31,
#   'NX573J': 1066,
#   'S70': 171,
#   'XT1068': 12304,
#   'Samsung SM-J110M': 1935,
#   'NX551J': 321,
#   '705-G': 237,
#   'LG-M257': 82,
#   'Samsung SM-G610M': 1225247,
#   'M6T': 559,
#   'Samsung SM-A505G': 9240,
#   'ML-JI11-M7_3G_PLUS': 168,
#   'LIO+': 685,
#   'XiaoMi MI 5s': 524,
#   'Vivo 8': 45,
#   'Lenovo K51c78': 82,
#   'Samsung SM-C7010': 157,
#   'Samsung SM-G3502L': 436,
#   'iPhone6,1': 17538,
#   'Twist Metal 32GB': 1639,
#   'C2304': 147,
#   'iPad6,8': 87,
#   'JOY': 987,
#   'vivo 1716': 6,
#   'Samsung SM-J110L': 75,
#   'Samsung GT-I9195': 964,
#   'LG-D390': 42,
#   'LGMS210': 186,
#   'iPhone12,5': 111271,
#   'XiaoMi Redmi 6 Pro': 605,
#   'DUB-LX1': 665,
#   'MS50G': 15089,
#   'Asus Z00UD': 7322,
#   'Vivo XI': 2269,
#   'Samsung SM-E500M': 1405,
#   'Samsung SM-P615': 132,
#   'C1604': 140,
#   'BLU STUDIO C HD': 24,
#   'iPhone8,2': 96357,
#   'WAS-LX1': 267,
#   'victor': 144,
#   'M9 Pro': 302,
#   'Samsung SM-N950U1': 335,
#   'LG-H735': 15,
#   'Nokia 6': 3363,
#   'Samsung SM-G7102T': 574,
#   'LG-X170fTV': 979,
#   'MS45S_A6': 1270,
#   '5085J': 2252,
#   'G_Max': 3243,
#   'Smartphone DL Horizon H8': 371,
#   'CPH1803': 109,
#   'GO3C Plus': 1650,
#   'HDT-9421G': 395,
#   'You': 2693,
#   'Q06': 128,
#   'LG-K580': 10354,
#   'XiaoMi MI 6': 6964,
#   'SC-02H': 16,
#   'RNE-L23': 344,
#   'Asus Z01FD': 29,
#   'Moto G (5)': 358078,
#   'vivo 1901': 67,
#   'M10A-Lite': 166,
#   'iPad11,1': 232,
#   'Moto G5 (XT1672)': 2846,
#   'LG-M151': 32,
#   'Lenovo YB1-X90F': 16,
#   'Samsung SM-G611MT': 306078,
#   'Twist 2': 11923,
#   'Quartzo UP': 1019,
#   'XiaoMi Redmi Note 3': 1448,
#   'Lenovo B8000-F': 478,
#   'HTC Desire 550': 30,
#   'BLU Grand X LTE': 336,
#   'DASH C MUSIC': 73,
#   'XiaoMi Redmi Note 9S': 6797,
#   'Samsung GT-S7582': 55,
#   'Samsung SM-F700F': 440,
#   'LG-K420': 1085,
#   'iPad4,4': 2336,
#   'C5': 1925,
#   'iPhone4,1': 99,
#   'Samsung SM-G355M': 1798,
#   'Samsung SM-A7050': 99,
#   'LM-Q710.FGN': 4961,
#   'Lenovo Z90-7': 143,
#   'WAS-LX3': 176,
#   'Samsung SM-G6000': 44,
#   'Samsung SM-G930F': 128283,
#   'iPhone10,2': 66386,
#   'GOME_U9': 754,
#   'XiaoMi Redmi K30': 19,
#   'Samsung SM-A300M': 7001,
#   'Asus X00ADA': 1825,
#   'ZB500KG': 673,
#   'Lenovo A6020a40': 3032,
#   'MS60F_PLUS': 1342,
#   'Nokia 6.1 Plus': 1730,
#   'Lenovo L78011': 228,
#   'fnac 5': 68,
#   'Samsung SM-A405FN': 1700,
#   'Asus X00BD': 196,
#   'LG M320': 275,
#   'HTC 10': 75,
#   'Samsung SM-N7502': 209,
#   'Tablet_DL_2820': 173,
#   'Lenovo L38041': 1851,
#   'Samsung SM-G965U1': 1728,
#   'LG-H818': 4830,
#   'Samsung SM-G928G': 4855,
#   'NX612J': 136,
#   'ENERGY XL': 65,
#   'Samsung SM-J320M': 134113,
#   'iPhone5,4': 6114,
#   'Lenovo K50-t5': 330,
#   'vernee_M5': 433,
#   'LND-AL30': 309,
#   'Lenovo K10e70': 188,
#   'Che2-L11': 59,
#   'Samsung SM-G920T': 58,
#   'iPhone8,4': 109386,
#   'Asus I001DB': 380,
#   'PTB7QSG_3G': 111,
#   'Samsung GT-S7582L': 4404,
#   'RNE-L22': 474,
#   'LG M250': 1160,
#   'Samsung GT-S6792L': 34,
#   'R2 LTE': 700,
#   'Samsung SM-A310M': 6609,
#   'Samsung SM-N960U1': 296,
#   'Samsung SM-T560': 164,
#   'GO 2': 95,
#   'Samsung SM-T380': 5,
#   'Quantum Go': 1740,
#   'Samsung SM-N975U': 51,
#   'Lenovo L18021': 342,
#   'Samsung SM-G900FD': 196,
#   'Samsung SM-G935L': 18,
#   'Samsung SM-G955N': 208,
#   'Samsung KDDI': 18,
#   'Asus Z017DC': 18016,
#   'XT1039': 259,
#   'Samsung SM-J320H': 1428,
#   'LG-H540': 4862,
#   'Samsung SM-T725': 1018,
#   'LG-M210': 22,
#   'LG-E425f': 67,
#   'Asus Z01KDA': 1490,
#   'XiaoMi Redmi Note 7 Pro': 1175,
#   'C6503': 55,
#   'LG-D125': 1116,
#   'LG-H340': 580,
#   'iPad8,7': 161,
#   'Nokia 7': 61,
#   'Samsung SM-J700H': 2067,
#   'MS40S': 1144,
#   'MS60Z': 1136,
#   'LG-D724': 344,
#   'Samsung SM-J415F': 93,
#   'Vivo 5R': 63,
#   'VIE-L09': 64,
#   'Samsung SM-T280': 4810,
#   'Asus Z01RD': 12654,
#   'M9-3G': 435,
#   'Samsung SM-G531M': 8637,
#   'Samsung SM-G891A': 317,
#   'Samsung SM-N920G': 2662,
#   'G6 Plus': 25,
#   'XT1635-02': 49188,
#   'Lenovo A1010a20': 1066,
#   'Samsung SM-N970F': 26783,
#   'Lenovo L58041': 330,
#   'BLU STUDIO G2': 636,
#   'XT1021': 136,
#   'VKY-L29': 96,
#   'Lenovo L78032': 1073,
#   'BLU ADVANCE 4.0 L2': 1420,
#   'GO5E': 5727,
#   'Samsung SM-G318ML': 80,
#   'Samsung SM-G960W': 460,
#   'XiaoMi Redmi 3': 409,
#   'Samsung SM-J200H': 859,
#   'LM-X410.F': 286957,
#   'Studio View XL': 370,
#   'D5322': 480,
#   'S10_Pro': 359,
#   'A3_Pro': 74,
#   'Samsung SM-A705MN': 259297,
#   'F8331': 204,
#   'LG-D805': 140,
#   'Samsung SM-G975U': 495,
#   'iPod7,1': 2018,
#   'K10': 19,
#   'Lenovo P2a42': 14,
#   'Le X526': 172,
#   'iPad8,1': 259,
#   'Samsung SM-G570F': 775,
#   'H3223': 575,
#   'PRA-LX1': 297,
#   'Samsung SM-G920A': 207,
#   'dolphin': 107,
#   'Samsung SM-A260G': 879,
#   'Samsung GT-S6810B': 35,
#   'Samsung SM-G955F': 146520,
#   'Asus X00DDB': 999,
#   'Asus X008DC': 72,
#   'XT1663': 30,
#   'LG-H422': 5419,
#   'Samsung SM-G955U1': 1377,
#   'LG-X240': 12120,
#   'Asus I01WD': 6630,
#   'Samsung GT-I8552': 21,
#   'LG-K500': 6037,
#   'Tablet_DL_4010': 194,
#   'TP601B': 46,
#   'LG-E615f': 159,
#   'Generic Smartphone': 40317411,
#   'Samsung SM-G973F': 153723,
#   'Samsung SM-G960U1': 1227,
#   'iPad7,11': 389,
#   'iPad4,7': 13,
#   'Lenovo TB-X705F': 5,
#   'Twist Mini': 15444,
#   'HT37Pro': 106,
#   'D2114': 398,
#   'Samsung SM-T285M': 13812,
#   'Samsung SM-G960F': 4928,
#   'Advance 4.0 L3': 377,
#   'Samsung SM-J600F': 56,
#   'LG-E475f': 36,
#   'LG-AS330': 21,
#   'C6843': 11,
#   'Samsung SM-J737U': 38,
#   'Samsung SM-A505GT': 629962,
#   'Samsung SM-A315G': 3557,
#   'Samsung GT-I9300I': 4346,
#   'Asus T00J': 417,
#   'D6633': 634,
#   'Asus X00DD': 180,
#   'SGP551': 536,
#   'Samsung SM-A310F': 172,
#   'Samsung SM-N950F': 47743,
#   'GOME 2017M27A': 1682,
#   'Samsung GT-S7275B': 232,
#   'K10000 Pro': 14,
#   'Samsung SM-A605FN': 798,
#   'Pixel C': 260,
#   'Samsung SM-T111M': 677,
#   'Asus X00TD': 711,
#   'XiaoMi MI 9 Transparent Edition': 161,
#   'Samsung SM-J610F': 133,
#   'LG-H910': 73,
#   'XT1635-03': 80,
#   'Moto G4 Plus': 96,
#   'Samsung SM-G900A': 30,
#   'LG-H870': 14397,
#   'Samsung SM-P355M': 1451,
#   '4055J': 1728,
#   'Positivo US2070': 35,
#   'exbom': 425,
#   'E2306': 99,
#   'Samsung GT-I9105P': 86,
#   'Samsung SM-G975W': 683,
#   'Samsung SM-J200BT': 48352,
#   'XiaoMi Redmi Note 8T': 41903,
#   'Samsung SM-J410F': 490,
#   '5046J': 937,
#   'Lenovo L38012': 467,
#   'F8332': 82,
#   'FRD-AL10': 131,
#   'iPhone9,1': 97042,
#   'Samsung SM-G800H': 9683,
#   'G3116': 1673,
#   'E6603': 261,
#   'Mi A1': 65,
#   'MZ-M5c': 297,
#   'Samsung SM-J410G': 581226,
#   'Samsung SM-G965F': 4924,
#   'LG-D690n': 7821,
#   'G': 1316,
#   'Samsung SM-G935A': 376,
#   'Samsung SM-G928F': 267,
#   'Samsung SM-N975U1': 79,
#   'Le X522': 652,
#   'Samsung SM-T510': 2703,
#   'Samsung SM-G900P': 1750,
#   'HP 7.1': 371,
#   'iPad11,3': 111,
#   'Samsung SM-T385M': 1830,
#   'BLL-L22': 42,
#   'Samsung SM-A9000': 89,
#   'Life One X2': 21,
#   'Samsung SM-G9650': 296148,
#   'Samsung SM-G610F': 20518,
#   'Samsung SM-N910C': 3935,
#   'BV9500': 42,
#   'Samsung SM-A605GN': 74419,
#   'LG-K430': 362463,
#   'iPhone7,1': 43379,
#   'Samsung GT-I9063T': 4805,
#   'XiaoMi MI MAX 3': 10312,
#   'XiaoMi Redmi 4A': 3299,
#   'Lenovo K53a48': 1543,
#   'Samsung SM-J106B': 1391,
#   'Samsung SM-G892A': 78,
#   'Samsung SM-A307GN': 39,
#   'R1 PLUS': 197,
#   'Samsung GT-S6313T': 349,
#   'Samsung SAMSUNG SM-N9005': 37,
#   'LG-V400': 4,
#   'Asus X00DDA': 13139,
#   'G3312': 355,
#   'Lenovo K8 Plus': 8176,
#   'Samsung GT-N7000': 197,
#   'Moto G': 101,
#   'LG-K200': 41869,
#   '5199I': 900,
#   'Motorola MZ608': 65,
#   'XT1650': 4705,
#   'BBD100-2': 675,
#   'Samsung SM-T700': 101,
#   'ATU-LX3': 39,
#   'Z831': 72,
#   'Samsung SM-M305M': 62999,
#   'XiaoMi Redmi 4X': 3650,
#   'XiaoMi Redmi Note 4X': 923,
#   'Samsung SAMSUNG-SM-J320A': 370,
#   'XT1040': 1669,
#   'Asus Z00LD': 2728,
#   'Samsung SM-N920S': 1139,
#   'LG-H873': 639,
#   'D2403': 491,
#   'Samsung GT-N7105T': 37,
#   'G4': 96,
#   'XiaoMi MI 8 Pro': 8354,
#   'Samsung GT-I9295': 668,
#   'iPad5,2': 147,
#   'BLA-L29': 637,
#   'Samsung SM-T835': 88,
#   'Asus X00ID': 18342,
#   'C NOTE 2': 705,
#   'E6633': 2577,
#   'Samsung SM-J720M': 6752,
#   'MZ-meizu C9': 70,
#   'Kindle': 1313,
#   'Samsung SM-G970U1': 96,
#   'Lenovo A6020a46': 172,
#   'Lenovo TB-8703F': 137,
#   'E6683': 52,
#   'ELUGA_A3_Pro': 302,
#   'Samsung SM-J500FN': 37,
#   'Samsung SM-T805M': 570,
#   'Asus X017D': 15434,
#   'Samsung GT-N5100': 162,
#   'Samsung SM-P605M': 43,
#   'XT1092': 93,
#   'XiaoMi MI MAX 2': 2172,
#   'Microsoft Virtual': 68,
#   'ML-SO-M7_3G_PLUS': 427,
#   'Nokia 3': 67,
#   'vivo NEX A': 472,
#   '9008N': 6670,
#   'XiaoMi MI 9 SE': 4252,
#   'XiaoMi MI CC9 Pro': 245,
#   '7048A': 13,
#   'C8': 100,
#   'NX569J': 155,
#   'LG-D175f': 1187,
#   'LG-D855': 515,
#   'Generic Feature Phone': 67,
#   'S9+': 392,
#   'TX92': 80,
#   'Lenovo P1c58': 332,
#   'moto g(6) play': 74154,
#   'PlayStation 4': 682,
#   'NP-852': 64,
#   'Samsung SM-A6060': 233,
#   'iPad4,1': 798,
#   'Z2': 119,
#   'Samsung SM-G930A': 2006,
#   'G8232': 49,
#   'LG-E989': 389,
#   'moto e5 plus': 59856,
#   'Twist (2018)': 13396,
#   'XT1580': 2871,
#   'Lumia 640': 281,
#   'Inettv': 45,
#   'MHA-L29': 6,
#   'Samsung SM-G955W': 48,
#   'Samsung SM-J120H': 87896,
#   'RNE-L21': 415,
#   'LM-G710': 455,
#   ...},
#  'os_family': {'Android': 72427957,
#   'Chrome OS': 18600,
#   'Fedora': 2867,
#   'FreeBSD': 215,
#   'Linux': 414139,
#   'Mac OS X': 513988,
#   'Other': 7902683,
#   'Ubuntu': 51097,
#   'Windows 10': 7487631,
#   'Windows 7': 3022648,
#   'Windows 8': 72571,
#   'Windows 8.1': 514360,
#   'Windows Mobile': 83,
#   'Windows Phone': 3342,
#   'Windows Vista': 6114,
#   'Windows XP': 25447,
#   'iOS': 9857804}}

# %%
dict_etapa2.keys()
# dict_etapa2.values()
# Out:
# dict_keys(['browser_family', 'os_family', 'device_family'])
